# %%
# ─── Cell: Define Retrieval & Attribute Functions ────────────────────────────
# !pip install --no-deps --quiet nltk rank_bm25 sentence-transformers tqdm

# ─── Imports & Setup ─────────────────────────────────────────────────────────
import os, heapq
import numpy as np
import nltk
import torch

from nltk.tokenize import word_tokenize, sent_tokenize
from nltk.corpus    import stopwords
from nltk.util      import everygrams
from transformers   import pipeline
from rank_bm25      import BM25Okapi
from sentence_transformers import SentenceTransformer, util
from tqdm.auto     import tqdm
# Out:
# 2025-05-26 09:40:11.886513: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:477] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1748252412.078439      35 cuda_dnn.cc:8310] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1748252412.134251      35 cuda_blas.cc:1418] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered

# %%
# Ensure NLTK assets
nltk.download("punkt")
nltk.download("stopwords")
stops = set(stopwords.words("english"))
# Out:
# [nltk_data] Downloading package punkt to /usr/share/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package stopwords to /usr/share/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!

# %%
# Device for encoder
device = "cuda" if torch.cuda.is_available() else "cpu"

# Path to the dump
DUMP_PATH = "/kaggle/input/wikidump/wikipedia-dump.txt"

# %%
# 1) Multiview Query Generator
ner = pipeline(
    "ner",
    model="dslim/bert-large-NER",
    tokenizer="dslim/bert-large-NER",
    aggregation_strategy="simple",
    device=0 if device=="cuda" else -1
)
# Out:
# config.json:   0%|          | 0.00/1.45k [00:00<?, ?B/s]
# model.safetensors:   0%|          | 0.00/1.33G [00:00<?, ?B/s]
# Some weights of the model checkpoint at dslim/bert-large-NER were not used when initializing BertForTokenClassification: ['bert.pooler.dense.bias', 'bert.pooler.dense.weight']
# - This IS expected if you are initializing BertForTokenClassification from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing BertForTokenClassification from the checkpoint of a model that you expect to be exactly identical (initializing a BertForSequenceClassification model from a BertForSequenceClassification model).
# tokenizer_config.json:   0%|          | 0.00/40.0 [00:00<?, ?B/s]
# vocab.txt:   0%|          | 0.00/213k [00:00<?, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/112 [00:00<?, ?B/s]
# Device set to use cuda:0

# %%
def generate_multiview_queries(question: str, max_ngram: int = 2) -> list[str]:

    #ner
    ents = {ent["word"] for ent in ner(question)}

    # n-grams
    toks = [
        t.lower() for t in word_tokenize(question)
        if t.isalpha() and t.lower() not in stops
    ]
    ngrams = {" ".join(g) for g in everygrams(toks, max_len=max_ngram)}
    
    return [q for q in (ents | ngrams) if len(q) > 1]

# %%
import os

for dirname, _, filenames in os.walk("/kaggle/input"):
    print(dirname, filenames)
# Out:
# /kaggle/input []
# /kaggle/input/wikidump ['wikipedia-dump.txt']

# %% [markdown]
# Topic Retriever

# %%
# 2) Paragraph Streamer
def iter_wiki_paragraphs(path: str):
    """Yield (title, paragraph) for each line ≥50 chars."""
    with open(path, encoding="utf-8") as f:
        for line in f:
            p = line.strip()
            if len(p) >= 50:
                yield "Wikipedia", p

# %%
# 3) Multiview BM25 Topic Retriever
def _process_chunk_multiview(paras, titles, queries, top_d, heap):
    tokenized = [
        [w for w in word_tokenize(p.lower()) if w.isalpha() and w not in stops]
        for p in paras
    ]
    bm25 = BM25Okapi(tokenized)
    all_scores = np.zeros(len(paras), dtype=float)
    for q in queries:
        q_tok = [w for w in word_tokenize(q.lower()) if w.isalpha()]
        all_scores = np.maximum(all_scores, bm25.get_scores(q_tok))
    for sc, t, p in zip(all_scores, titles, paras):
        if len(heap) < top_d:
            heapq.heappush(heap, (sc, t, p))
        elif sc > heap[0][0]:
            heapq.heapreplace(heap, (sc, t, p))

# %%
def local_topic_retrieve_mv(
    question: str,
    top_d: int = 5,
    chunk_size: int = 50_000
) -> list[tuple[float,str,str]]:
    """
    Multiview BM25 over the full dump, in chunks of `chunk_size`.
    Returns top_d (score, title, paragraph).
    """
    queries = generate_multiview_queries(question)
    heap, buffer, titles = [], [], []
    for title, para in tqdm(iter_wiki_paragraphs(DUMP_PATH), desc="Topic retrieve"):
        buffer.append(para); titles.append(title)
        if len(buffer) >= chunk_size:
            _process_chunk_multiview(buffer, titles, queries, top_d, heap)
            buffer, titles = [], []
    if buffer:
        _process_chunk_multiview(buffer, titles, queries, top_d, heap)
    return sorted(heap, key=lambda x: -x[0])[:top_d]

# %%
# Quick sanity-check: count first 5 paragraphs
dump_path = "/kaggle/input/wikidump/wikipedia-dump.txt"
for i, (t, p) in enumerate(iter_wiki_paragraphs(dump_path)):
    print(f"[{i}] {t} → {p[:80]}…")
    if i >= 4: break
# Out:
# [0] Wikipedia → anarchism is political philosophy and movement that rejects all involuntary coer…
# [1] Wikipedia → autism is developmental disorder characterized by difficulties with social inter…
# [2] Wikipedia → diffusely reflected sunlight relative to various surface conditions albedo meani…
# [3] Wikipedia → or is the first letter and the first vowel letter of the modern english alphabet…
# [4] Wikipedia → alabama is state in the southeastern region of the united states it is bordered …

# %%
# ─── Cell 12: Test Local‐dump Topic Retriever ───────────────────────────────
question = "What is the ruling party of the country that hosted the 2016 Olympics?"
docs = local_topic_retrieve_mv(question, top_d=50, chunk_size=50_000)

print("Top 50 paragraphs from local dump:")
for sc, t, p in docs:
    print(f"{sc:.1f} → {t}: {p[:100]}…")

print(f"Retrieved {len(docs)} paragraphs.")
# Out:
# Topic retrieve: 0it [00:00, ?it/s]
# Top 50 paragraphs from local dump:
# 17.7 → Wikipedia: for the winter olympics in st moritz switzerland total of eight sports venues were used the five ven…
# 17.5 → Wikipedia: right horse guards parade hosted the beach volleyball events at the summer olympics in london copaca…
# 17.3 → Wikipedia: kazakoshi park arena is an indoor arena located in karuizawa nagano japan constructed in with an ope…
# 17.2 → Wikipedia: the human rights party or kanakpak sethi manus is cambodian political party founded on july led by k…
# 17.1 → Wikipedia: the adler arena trade and exhibition center адлер арена is an seat speed skating oval in the olympic…
# 16.6 → Wikipedia: london hosted the olympic games in and the summer olympics made london the first city to have hosted…
# 16.6 → Wikipedia: snow harp is cross country skiing venue located in hakuba nagano japan for the winter olympics the v…
# 16.6 → Wikipedia: paris has hosted several olympiads and and will host in paris will be the second city in the modern …
# 16.5 → Wikipedia: los angeles hosted the olympic games in and and will host again in the summer olympics made los ange…
# 16.4 → Wikipedia: the faliro sports pavilion arena which is part of the faliro coastal zone olympic complex is an indo…
# 16.3 → Wikipedia: for the summer olympics there have been fourteen olympic sports that have been discontinued from the…
# 16.3 → Wikipedia: poznań was bid by the city of poznań and the polish olympic committee to host the summer youth olymp…
# 16.3 → Wikipedia: piscines bernat picornell is swimming venue situated in the olympic ring in montjuïc barcelona the v…
# 16.3 → Wikipedia: for the winter olympics in albertville france total of thirteen sports venues were used val isère ha…
# 16.2 → Wikipedia: stadio olimpico di torino turin olympic stadium as football venue in for the winter olympics it host…
# 16.2 → Wikipedia: for the winter olympics in innsbruck austria total of eight sports venues were used luge made its de…
# 16.1 → Wikipedia: lausanne was successful bid by the city of lausanne and the swiss olympic association to host the wi…
# 16.1 → Wikipedia: claude quenneville is canadian sports commentator in quebec he served as the french language radio v…
# 16.1 → Wikipedia: five cities made the shortlist with their bids to host the summer olympics formally known as games o…
# 16.0 → Wikipedia: dundumwezi is modified word from its original dundumwenze which means male mountain is constituency …
# 16.0 → Wikipedia: communist party congress could refer to ruling or former ruling communist parties congress of the so…
# 15.9 → Wikipedia: there were six bids initially submitted for the summer olympics tokyo was ultimately elected as the …
# 15.9 → Wikipedia: munich olympiastadion for the summer olympics total of thirty two sports venues were used majority o…
# 15.9 → Wikipedia: olympic flame at the opening ceremony of summer olympics for the summer olympics total of thirty fiv…
# 15.9 → Wikipedia: tokyo is major center for sports in japan its professional sports teams compete in baseball football…
# 15.9 → Wikipedia: picture of the gate to the los angeles memorial coliseum the coliseum served as the main stadium for…
# 15.8 → Wikipedia: matías schmitt born june is an argentine snowboarder he competed in the winter olympics sports caree…
# 15.8 → Wikipedia: long track speed skating events at the winter olympics for the winter olympics in nagano japan total…
# 15.8 → Wikipedia: olympic stadium after the remodeling for the european athletics championships it hosted the athletic…
# 15.8 → Wikipedia: training at the time of youth winter olympics the olympia is speed skating venue located in innsbruc…
# 15.7 → Wikipedia: scotiabank then pengrowth saddledome in july this venue which hosted the figure skating and ice hock…
# 15.7 → Wikipedia: bids were due by november the candidates cities were selected on december and lausanne was elected h…
# 15.7 → Wikipedia: bergiselschanze in the venue hosted the large hill ski jumping event at the winter olympics for the …
# 15.6 → Wikipedia: the olympic green in subway line sign the olympic green is an olympic park in chaoyang district beij…
# 15.5 → Wikipedia: right lake wendouree hosted the canoeing events when the summer olympics were in melbourne the eiska…
# 15.5 → Wikipedia: map of host cities and countries of the modern summer orange and winter blue olympics tap or hover o…
# 15.5 → Wikipedia: the bolshoy ice dome is multi purpose indoor arena located in olympic park sochi russia opened in th…
# 15.5 → Wikipedia: the taiwan communist party was social democratic political party in taiwan it was established on jun…
# 15.4 → Wikipedia: right bois de vincennes hosted the first archery competitions for the summer olympics at paris in pa…
# 15.4 → Wikipedia: the popular action of equatorial guinea is political party in the equatorial guinea it is led by car…
# 15.4 → Wikipedia: the winter olympics which would have been officially known as the were to have been celebrated from …
# 15.4 → Wikipedia: olimpiysky pool moscow as seen in the swimming pool at the olimpiysky sports complex is covered swim…
# 15.4 → Wikipedia: guadalajara was bid by the city of guadalajara and the comité olímpico mexicano to host the summer y…
# 15.4 → Wikipedia: the popular union of equatorial guinea is political party in the equatorial guinea it is led by dani…
# 15.4 → Wikipedia: birkebeineren ski stadium is cross country skiing and biathlon venue located in lillehammer norway s…
# 15.4 → Wikipedia: right start at the cresta run in st moritz host of the skeleton events for both the and winter olymp…
# 15.3 → Wikipedia: aerial view of the current bobsleigh luge and skeleton track at the winter games this was where the …
# 15.3 → Wikipedia: is mountain located in yamanouchi nagano japan for the winter olympics it hosted the alpine skiing s…
# 15.2 → Wikipedia: the camp olímpic de tir amb arc was temporary venue located in barcelona it hosted the archery compe…
# 15.2 → Wikipedia: the hon clyde mascoll is politician from barbados he is former leader of the democratic labour party…
# Retrieved 50 paragraphs.

# %% [markdown]
# save the docs

# %%
import os, json
os.makedirs("cache", exist_ok=True)
docs_path = "cache/docs.json"

# quick check
assert len(docs) > 0, "No paragraphs retrieved—check your retriever!"
print("Sample:", docs[0])

# save
with open(docs_path, "w", encoding="utf-8") as f:
    json.dump([{"score":s,"title":t,"para":p} for s,t,p in docs], f, ensure_ascii=False, indent=2)
print("Saved to", docs_path)

# verify
size = os.path.getsize(docs_path)
print("File size:", size, "bytes")
loaded = json.load(open(docs_path, "r", encoding="utf-8"))
print("Loaded entries:", len(loaded))
# Out:
# Sample: (17.741650576283966, 'Wikipedia', 'for the winter olympics in st moritz switzerland total of eight sports venues were used the five venues used for the winter olympics were reused for these games three new venues were added for alpine skiing which had been added to the winter olympics program twelve years earlier in garmisch partenkirchen germany allied occupied germany during the games as of the bob run continues to be used for bobsleigh and the cresta run for skeleton while alpine skiing remains popular in st moritz venues venue sports capacity ref around the hills of st moritz cross country skiing nordic combined cross country skiing not listed cresta run skeleton not listed kulm ice hockey not listed olympiaschanze st moritz ski jumping nordic combined ski jumping not listed olympic stadium opening closing ceremonies figure skating ice hockey final speed skating not listed piz nair alpine skiing not listed st moritz celerina olympic bobrun bobsleigh not listed suvretta ice hockey not listed before the olympics st moritz hosted the winter olympics previously in all five venues from those games were reused for the winter olympics st moritz hosted the fibt world championships in four man four man two man two man and switzerland itself hosted the ice hockey world championships twice in between the and games doing so in and though neither took place in st moritz as an alpine skiing venue st moritz hosted the fis alpine world ski championships in during the olympics midway through the second run of the bobsleigh four man event water pipe burst which halted competition they still completed all four runs of the event after the olympics the ski jump was renovated in to get it to point of it closed in the bob run has hosted the fibt world championships sixteen more times since the games most recently in st moritz hosted its first recorded alpine skiing world cup event in the city hosted the alpine skiing world championships in and references')
# Saved to cache/docs.json
# File size: 168914 bytes
# Loaded entries: 50

# %%
p = "./cache/docs.json"

fil = json.load(open(p, "r", encoding="utf-8"))
fil
# Out:
# [{'score': 17.741650576283966,
#   'title': 'Wikipedia',
#   'para': 'for the winter olympics in st moritz switzerland total of eight sports venues were used the five venues used for the winter olympics were reused for these games three new venues were added for alpine skiing which had been added to the winter olympics program twelve years earlier in garmisch partenkirchen germany allied occupied germany during the games as of the bob run continues to be used for bobsleigh and the cresta run for skeleton while alpine skiing remains popular in st moritz venues venue sports capacity ref around the hills of st moritz cross country skiing nordic combined cross country skiing not listed cresta run skeleton not listed kulm ice hockey not listed olympiaschanze st moritz ski jumping nordic combined ski jumping not listed olympic stadium opening closing ceremonies figure skating ice hockey final speed skating not listed piz nair alpine skiing not listed st moritz celerina olympic bobrun bobsleigh not listed suvretta ice hockey not listed before the olympics st moritz hosted the winter olympics previously in all five venues from those games were reused for the winter olympics st moritz hosted the fibt world championships in four man four man two man two man and switzerland itself hosted the ice hockey world championships twice in between the and games doing so in and though neither took place in st moritz as an alpine skiing venue st moritz hosted the fis alpine world ski championships in during the olympics midway through the second run of the bobsleigh four man event water pipe burst which halted competition they still completed all four runs of the event after the olympics the ski jump was renovated in to get it to point of it closed in the bob run has hosted the fibt world championships sixteen more times since the games most recently in st moritz hosted its first recorded alpine skiing world cup event in the city hosted the alpine skiing world championships in and references'},
#  {'score': 17.518419295818905,
#   'title': 'Wikipedia',
#   'para': 'right horse guards parade hosted the beach volleyball events at the summer olympics in london copacabana stadium hosted the volleyball preliminaries for the summer olympics in rio de janeiro for the summer olympics there are venues that have been or will be used for beach volleyball beach location games events notes atlanta beach clayton county international park jonesboro clayton county georgia usa beach volleyball at the summer olympics artificial beach bondi beach bondi beach waverley council eastern suburbs sydney new south wales australia beach volleyball at the summer olympics ocean coast beach faliro olympic beach volleyball centre faliro coastal zone olympic complex faliro athens greece beach volleyball at the summer olympics artificial beach chaoyang park beach volleyball ground chaoyang park chaoyang district beijing china beach volleyball at the summer olympics artificial beach with sand imported from hainan horse guards parade whitehall london england uk beach volleyball at the summer olympics artificial beach on royal parade grounds copacabana beach copacabana stadium copacabana beach copacabana rio de janeiro brazil beach volleyball at the summer olympics ocean coast beach shiokaze park stadium shiokaze park tokyo waterfront tokyo kanto japan beach volleyball at the summer olympics see also list of olympic venues in volleyball references'},
#  {'score': 17.29930767868344,
#   'title': 'Wikipedia',
#   'para': 'kazakoshi park arena is an indoor arena located in karuizawa nagano japan constructed in with an opening ceremony taking place in it hosted the curling competition for the winter olympics in nagano because it was in karuizawa the town became the first venue to host events at both the summer and winter olympics at the summer olympics in tokyo karuizawa hosted the equestrian events references winter olympics official report volume pp icing org profile of the venue shinmai co jp winter olympics profile of the arena'},
#  {'score': 17.213456148257933,
#   'title': 'Wikipedia',
#   'para': 'the human rights party or kanakpak sethi manus is cambodian political party founded on july led by kem sokha critics allege that its foundation is meant to weaken opposition parties and is driven by the ruling party this sentiment however seems to be driven by the ruling party themselves as kem sokha has long been very vocal critic of the ruling cpp party at the time of its foundation the party claimed to have between and members nationwide human rights party is the first party in cambodia to adopt the check and balance system changing the culture of one man ruling parties which most parties in cambodia adopt it is also the first party in cambodia to have its major leaders elected in its convention its popularity has been dramatically increasing in cambodia especially in the countryside in the july parliamentary elections the ruling party won landslide majority and the human rights party took third place in it merged with the sam rainsy party to form the cambodia national rescue party electoral performance general election election leader votes seats position government kem sokha rd communal election election leader votes communes councillors position kem sokha rd references external links hrp website khmer french english habeas corpus net pro justice and democracy web publishes page in english and spanish on cambodia'},
#  {'score': 17.069092988406577,
#   'title': 'Wikipedia',
#   'para': 'the adler arena trade and exhibition center адлер арена is an seat speed skating oval in the olympic park sochi russia it opened in and looks like an iceberg or ice fault the center hosted the speed skating events at the winter olympics original plans for after the olympics were for the adler arena to be turned into an exhibition center it cost million to build the venue including the temporary works for the olympics before the olympics it hosted the russian speed skating championships in december and the world single distance speed skating championships from to march construction crystal face theme is supported by angular walls and triangular stained glass windows the gray and white color of the building enhances this impression the walls along the sides of the skating rink are made transparent so that spectators can look outside the skating center is designed to make the utmost use of local natural features track records men distance skater time date event ronald mulder february winter olympics stefan groothuis february winter olympics zbigniew bródka february winter olympics ivan skobrev february test competition sven kramer february winter olympics jorrit bergsma february winter olympics teampursuit laps jan blokhuijsensven kramerkoen verweij february winter olympics combination skater points date match michel mulder february winter olympics sprint dmitry lobkov december national championship all round ivan skobrev december national championship women distance skater time date event lee sang hwa february winter olympics zhang hong february winter olympics jorien ter mors february winter olympics ireen wüst february winter olympics martina sáblíková february winter olympics teampursuit laps marrit leenstrajorien ter morsireen wüst february winter olympics combination skater points date match lee sang hwa february winter olympics sprint olga fatkulina december national championship all round yekaterina shikhova december national championship source www info other uses the skating centre hosted the world robot olympiad russia hosted their fed cup world group semifinals tie at the adler arena references external links adler arena on www info'},
#  {'score': 16.649201347941414,
#   'title': 'Wikipedia',
#   'para': 'london hosted the olympic games in and the summer olympics made london the first city to have hosted the modern games of three olympiads london is the only city in the united kingdom to have ever hosted the olympics the united states is the only country to have hosted summer olympics on more occasions than the uk also london is the only city to have bid more than once and still hold record british participation in olympic events both as competitor and as host is the responsibility of the british olympic association summer olympics london olympics the summer olympics the games of the iv olympiad were the fifth modern olympic games and the third to be hosted outside of athens greece the international olympic committee considers them the fourth olympic games discounting the intercalated summer olympics the olympic games were scheduled to take place in rome but the eruption of mount vesuvius on april required the italian government to redirect funds away from the olympics the events took place between april and october with nations participating in events the british team easily topped the unofficial medal count finishing with three times as many medals as the second place united states summer olympics the summer olympics the games of the xiii olympiad were scheduled to be held in london awarded in they were however cancelled due to world war ii these games would have celebrated the th anniversary of the modern olympiad summer olympics the summer olympics the games of the xiv olympiad were the first to be held after world war ii with the summer olympics having been cancelled due to the war showing collective unity after the war nations competed in different events between july and august germany and japan were not invited to the games due to security reasons unlike the previous time the uk hosted the olympics the british athletes did not have high medal count finishing th in the unofficial medal count with only medals summer olympics the summer olympics the games of the xxx olympiad took place between july and august the london olympic bid was announced as the winner of the bidding process on july following unsuccessful bid attempts for previous olympics by manchester and birmingham team gb finished rd with gold medals and total medals representing their best medal haul since london first hosted the olympics in summer paralympics the summer paralympics were the fourteenth paralympics and took place between august and september at the summer olympics venues in london external links london olympic games official website london olympic games information portal commentary on olympic park'},
#  {'score': 16.59422882944778,
#   'title': 'Wikipedia',
#   'para': 'snow harp is cross country skiing venue located in hakuba nagano japan for the winter olympics the venue hosted the cross country skiing and the cross country skiing portion of the nordic combined events completed in test events were held in the venues consisted of three courses that were and in length respectively it hosted events during the games the most of any venue references winter olympics official report volume pp hakuba nagano venue profile shinmai co jp winter olympics profile snowjapan com profile'},
#  {'score': 16.554317816813846,
#   'title': 'Wikipedia',
#   'para': 'paris has hosted several olympiads and and will host in paris will be the second city in the modern games to have hosted three olympiads when paris hosts the summer olympics the other being london the french national olympic and sports committee oversees france interests in the olympics summer olympics paris summer olympics the summer olympics the games of the ii olympiad were the third modern olympics and the inaugural hosted outside of athens greece the international olympic committee considers them the second olympics discounting the intercalated summer olympics the summer olympics were held simultaneously with the world fair the events took place between may and october with nations participating in events the french team topped the unofficial medal count finishing with three times as many medals as the second place united states while fielding ten times as many athletes summer olympics the summer olympics the games of the viii olympiad were the second to be held after world war showing collective unity after the war nations competed in different events between may and july germany was not invited to the games due to security reasons unlike the previous time france hosted the olympics the french athletes did not have high medal count finishing rd in the unofficial medal count with only medals summer olympics the summer olympics the games of the xxxiii olympiad will take place from july to august the paris olympic bid was announced as the winner of the bidding process on september following unsuccessful bid attempts for previous olympiads summer paralympics the summer paralympics will be the seventeenth paralympics and will take place between august and september at the summer olympics venues in paris external links paris olympic games official website'},
#  {'score': 16.49412079690418,
#   'title': 'Wikipedia',
#   'para': 'los angeles hosted the olympic games in and and will host again in the summer olympics made los angeles the third city to have hosted the modern games of three olympiads los angeles will be the only city in the united states to have ever hosted the olympics three times american participation in olympic events both as competitor and as host is the responsibility of the united states olympic committee summer olympics the summer olympics the games of the olympiad were the eleventh modern olympic games and the eighth to be hosted outside of athens greece the international olympic committee considers them the tenth olympic games discounting the intercalated summer olympics the events took place between july and august with nations participating in events summer olympics the summer olympics the games of the xxiii olympiad was held between july and august the soviet union and its satellites boycotted the games summer olympics the summer olympics games of the xxxiiv olympiad will take place between july and august summer paralympics the summer paralympics will be the eighteen paralympic games and will take place in los angeles for the first time external links la'},
#  {'score': 16.373430619215696,
#   'title': 'Wikipedia',
#   'para': 'the faliro sports pavilion arena which is part of the faliro coastal zone olympic complex is an indoor arena in palaio faliro in athens greece it is nicknamed the little peace and friendship stadium due to its similarity in design and close proximity to the peace and friendship stadium it was the site of the athens summer olympics preliminary matches of handball as well as the taekwondo competition the arena seats for handball matches of olympics though only seats were made publicly available during the olympics history the arena was completed on december and it officially opened on august shortly before the olympics began in june the arena hosted the th mad video music awards held by mad tv and hosted by themis georgantas the prodigy had sold out concert event at the arena tiesto performed at the arena during his kaleidoscope world tour the arena is also known as long time venue for holiday on ice shows it also hosted the greek legends event by riot games league of legends lan tournament in june and it hosted the finals of the league of legends greek championship season in the th and january co organized by riot games ast and inspot references external links summer olympics official report volume pp gr profile faliro arena stadia gr'},
#  {'score': 16.3471222533474,
#   'title': 'Wikipedia',
#   'para': 'for the summer olympics there have been fourteen olympic sports that have been discontinued from the program as of the summer olympics in london for the summer olympics in rio de janeiro golf and rugby union were reinstated as olympic sports though the latter was as rugby sevens as of there have been eight baseball two basque pelota one cricket one croquet two golf one jeu de paume two lacrosse five polo one racquets five rugby union fifteen side four softball five tug of war and one water motorsports venues used for the summer olympics baseball and softball now governed by single international federation and thus treated by the international olympic committee ioc as two disciplines of single sport will be part of the summer olympics program in tokyo the sports are not included in paris plan for the games but are part of los angeles plan for the games baseball right atlanta fulton county stadium hosted the baseball events for the summer olympics games venue other sports hosted at venue for those games capacity ref los angeles dodger stadium demonstration none seoul jamsil baseball stadium demonstration none barcelona camp municipal de beisbol de viladecans none hospitalet de llobregat baseball stadium final none atlanta atlanta fulton county stadium none sydney blacktown olympic park softball sydney baseball stadium final modern pentathlon riding running athens olympic baseball centre none beijing wukesong baseball field none basque pelota right games venue other sports hosted at venue for those games capacity ref paris neuilly sur seine none not listed barcelona pavelló de la vall hebron demonstration volleyball volleyball basque pelota cricket right vélodrome de vincennes hosted the cricket matches at the summer olympics in paris games venue other sports hosted at venues for those games capacity ref paris vélodrome de vincennes cycling football gymnastics rugby union not listed croquet right games venue other sports hosted at venue for those games capacity ref paris bois de boulogne polo tug of war not listed jeu de paume right queen club hosted the jeu de paume events for the summer olympics in london games venue other sports hosted at venue for those games capacity ref london queen club racquets not listed lacrosse right games venue other sports hosted at venue for those games capacity ref st louis francis field archery athletics cycling football gymnastics roque tennis tug of war weightlifting wrestling london white city stadium archery athletics cycling track diving field hockey football gymnastics rugby union swimming tug of war water polo final wrestling polo right ostend hosted the polo events for the summer olympics in antwerp games venue other sports hosted at venue for those games capacity ref paris bois de boulogne croquet tug of war not listed london hurlingham club none not listed antwerp ostend sailing not listed paris bagatelle none saint cloud none berlin mayfield equestrian dressage racquets right games venue other sports hosted at venues for those games capacity ref london queen club jeu de paume not listed roque right games venue other sports hosted at venue for those games capacity ref st louis francis field archery athletics cycling football gymnastics lacrosse tennis tug of war weightlifting and wrestling rugby union fifteen side softball right blacktown olympic stadium hosted the softball events for the summer olympics in sydney games venue other sports hosted at venue for those games capacity ref atlanta golden park none sydney blacktown olympic park baseball athens olympic softball stadium none not listed beijing fengtai softball field none tug of war right games venue other sports hosted at venue for those games capacity ref paris bois de boulogne croquet polo not listed st louis francis field archery athletics cycling football gymnastics lacrosse roque tennis weightlifting and wrestling london white city stadium archery athletics cycling track diving field hockey football gymnastics lacr ...
#  {'score': 16.335045140998613,
#   'title': 'Wikipedia',
#   'para': 'poznań was bid by the city of poznań and the polish olympic committee to host the summer youth olympics poznan withdrew their bid on october for financial reasons history poznań was revealed to be one of the bidding cities for the summer youth olympics when the ioc announced who the applicants were on march poznań was one of the eight cities that hosted games during the uefa euro championship the stadion miejski hosted three matches during the championship poznań in last few years was host city of such sport events as the men indoor hockey world cup in the city hosted the academic canoeing world cup academic basketball world cup european male basketball cup and the european athletic cup for vets in the city hosted the academic futsal world cup and was one of the host cities for the uefa european under football championship on october the city council rejected the proposed budget for the bid there was lack of financial guarantees from the city organizer and the city withdrew its bid buenos aires was ultimately elected as the host city of the summer youth olympic games on july previous bids view of poznań old town poznań bid to host the summer youth olympics but lost to nanjing by only five votes they bid to host the summer youth olympics but failed to become candidate those games were ultimately awarded to singapore previous bids by other polish cities zakopane bid to host the winter olympics but lost to turin see also poland at the olympics bids for the summer youth olympics references'},
#  {'score': 16.33118298523432,
#   'title': 'Wikipedia',
#   'para': 'piscines bernat picornell is swimming venue situated in the olympic ring in montjuïc barcelona the venue consists of three swimming pools indoor pool outdoor pool and pool for diving it hosted the swimming events synchronized swimming events the water polo final and the swimming part of the modern pentathlon event for the summer olympics the swimming pools are for public use and are open all year long history the venue named after the catalan swimmer and founder of the spanish swimming federation bernat picornell richier was built to host the european aquatics championships in refurbishment works began for the olympics the main changes were that the training pool was covered and that temporary grandstands were installed boosting the capacity to more than spectators since the olympics the outdoor swimming pool with capacity for spectators has hosted several spanish and catalan swimming championships as well as the synchronized swimming events for the world aquatics championships in it hosted the water polo events for the world aquatics championships since the city of barcelona repeated as host ten years later see also piscina municipal de montjuïc references summer olympics official report volume pp external links official site'},
#  {'score': 16.297272864156565,
#   'title': 'Wikipedia',
#   'para': 'for the winter olympics in albertville france total of thirteen sports venues were used val isère has been part of the alpine skiing world cup since the late while tignes served as host of the first freestyle world ski championships in most of the venues used were constructed between and mid with the test events taking place in late and early it was the last winter olympics with an outdoor speed skating rink which led to weather issues for three of the ten events three cross country skiing events were run in snowstorms while the men km biathlon was found to be too short the downhill events in alpine skiing were criticized for being too steep freestyle skiing made its official debut at these games with the men winner being stormed after his win while the women winner won her event in snow storm la plagne hosted the skeleton world championships in while val isère hosted the alpine world ski championships in venues venue sports capacity ref anneau de vitesse speed skating la halle de glace olympique figure skating short track speed skating la plagne bobsleigh luge not listed les arcs speed skiing demonstration not listed les menuires alpine skiing men slalom not listed les saisies biathlon cross country skiing méribel alpine skiing women méribel ice palace ice hockey patinoire olympique de pralognan la vanoise curling demonstration théâtre des cérémonies ceremonies opening closing tignes freestyle skiing not listed tremplin du praz nordic combined ski jumping jumping nordic combined cross country skiing val isère alpine skiing men downhill super giant slalom giant slalom and combined not listed before the olympics albertville is part of the rhône alpes region in france that had hosted the winter olympics twice with chamonix in and grenoble in jean claude killy the triple gold medalist in the men alpine skiing event at the grenoble games had become successful businessman when he suggested the idea of the winter olympics in december to michel barnier politician in the savoie department proposal was sent to the albertville town council six months later followed regional studies done during presentation and media operations for the bid took place from to its awarding in by the international olympic committee after five rounds of voting albertville was selected over sofia bulgaria falun sweden val isère had its first alpine skiing world cup events run in december the olympic test held there in december was won by winter olympics men downhill gold medalist leonhard stock of austria tignes hosted of the first fis freestyle world ski championships in february construction on most of the venues took place between and mid in time for the late and early test events during the olympics this was the last winter olympics in which speed skating was held outdoors as result weather played factor in three of the ten events run in the women on february the start of the event was delayed one hour the let the outdoor oval ice harden warm weather delayed the women event for an hour on the th the following day the men event was held in steady rain norway geir karlstad the gold medalist in the men commented in the post race press conference that didn like soft ice up to now but now do this led to the international skating union passing rule after the winter games stating that all olympic speed skating competitions should be held indoors which it has been since the winter olympics in lillehammer for the alpine skiing downhill courses complaints were given that the courses were too steep on the men side the complaints from downhill skiers that it was more like super giant slalom course rather than classical downhill course the women course was long and had the steepest vertical drop ever at further making the women downhill challenge was an impending snowstorm that forced race officials to move up the start time and send the skiers out at shorter than usual intervals an intermittent fog also set in during the women downhill cross country skiing ...
#  {'score': 16.220804878361456,
#   'title': 'Wikipedia',
#   'para': 'stadio olimpico di torino turin olympic stadium as football venue in for the winter olympics it hosted the opening and closing ceremonies for the winter olympics in turin italy total of fifteen sports venues were used venue construction ran from to cesana pariol had to have turns and modified following the luge world cup in january but they were not cleared out until october winds postponed the nordic combined team event for day many of the venues served as host for the winter universidade the following year venues city venue sports capacity ref oval lingotto speed skating palavela figure skating short track speed skating palasport olimpico ice hockey final stadio olimpico grande torino ceremonies opening closing torino esposizioni ice hockey mountain venue sports capacity ref bardonecchia snowboarding cesana pariol bobsleigh luge skeleton cesana san sicario biathlon pinerolo palaghiaccio curling pragelato nordic combined ski jumping ski jumping pragelato plan cross country skiing nordic combined cross country skiing san sicario fraiteve alpine skiing women combined downhill downhill super sauze oulx jouvencaux freestyle skiing sestriere borgata alpine skiing men combined downhill downhill super sestriere colle alpine skiing combined slalom giant slalom slalom before the olympics palavela during the winter olympics the venue hosted the figure skating and short track speed skating events during those games stadio olimpico in was known as stadio benito mussolini for the fifa world cup that took place that year the stadium hosted two matches including the quarterfinal match between czechoslovakia and switzerland turin was selected by the italian olympic committee to be selected to host the winter olympics in march it was awarded the winter olympics on june cesana pariol construction began in and was completed in after luge world cup test event in january that was abandoned to accidents this led to modifications of turns and and retest of the track that was approved by the international luge federation fil in october oval lingotto opened on december palavela constructed in was modified for the games to host figure skating and short track speed skating events san sicario fraiteve hosted an alpine skiing world cup in february and was modified to make the women super event more challenging torino esposizinoi was constructed in and refurbished in time for the games to host the preliminary ice hockey matches venues were selected between may and the summer of construction of the venues ran between the summers of and the venues were turned over for use of the games between the summer of and february new construction included cesana pariol cesana san sicario pragelato pragelato plan and sauze ouix jouvencaux while the other venues used were refurbished or expanded sustainability efforts were applied on all venues but the most noted in the olympics report were cesana pariol and pragelato plan the most expensive venue construction in the mountain area was cesana pariol at million while the most expensive city venue used for competition in the city area was oval lingotto at million during the olympics picture of turns through right to left of cesana pariol during the winter olympics bobsleigh luge and skeleton events took place at this venue the men curling bronze medal match at pinerolo between great britain and the united states was interrupted by streaker wearing rubber chicken as loin cloth at cesana pariol the women singles luge event had thirteen crashes or near crashes during the four runs among those who crashed were american samantha retrosi who was knocked unconscious at the end of the second run while italy anastasia oberstolz antonova crashed out during the first run during the men super alpine skiing event at sestriere borgata seventeen skiers had gone down the course in the morning portion of the event before it was halted to heavy snowfall the event was restarted in the afternoon with all morning results cancelled n ...
#  {'score': 16.157061540484325,
#   'title': 'Wikipedia',
#   'para': 'for the winter olympics in innsbruck austria total of eight sports venues were used luge made its debut at these games but were marred by the death of british slider two weeks prior to the games second ski jumping event debuted and the best two out of three jumps were used in both events for the only time in the history of the winter olympics all eight venues would be used again when the winter games returned to innsbruck twelve years later though the venues would undergo renovations in time for the games venues venue sports capacity ref axamer lizum alpine skiing all but men downhill not listed bergiselschanze ski jumping large hill bob und rodelbahn igls bobsleigh luge not listed speed skating messehalle ice hockey olympiahalle figure skating ice hockey patscherkofel alpine skiing men downhill not listed seefeld biathlon cross country skiing nordic combined ski jumping normal hill not listed before the olympics before the winter games innsbruck hosted several world and european championships they hosted the alpine world ski championships both in and in innsbruck served as host to the fis nordic world ski championships innsbruck hosted its first bobsleigh world championships in in the two man event then hosted again in when the bobsleigh part of the track was used as test event for the games luge was also completed at the same time though kazimierz kay skrzypeski of great britain was killed in practice run on the luge part of the track two weeks before the start of the games igls also served as host of the european luge championships in though the track used was not constructed until since ski jumping season bergiselschanze has been part of the four hills tournament seefeld hosted the biathlon world championships in which also served as test event for the games during the olympics the ski jumping events were the only one in winter olympic history to use the best two out of three jumps for medals this saved finland veikko kankkonen in the normal hill event after he followed disastrous first jump with the longest second and the second longest third jumps after the olympics bergiselschanze continued to play host as one of the hills for the four hills tournament innsbruck would host the winter olympics twelve years later following the withdrawal of denver colorado in the united states for those games in late all eight venues from the games were used for the games with some improvements the bobsleigh and luge tracks were demolished and converted into an artificially refrigerated combination track the first of its kind in the world ski jumps at bergsiel and seefeld both had improving judging stations two new artificial ice rinks were built one for figure skating and the other for ice hockey eischnellaufen had new refrigeration done on its lap circuit references'},
#  {'score': 16.098253161597384,
#   'title': 'Wikipedia',
#   'para': 'lausanne was successful bid by the city of lausanne and the swiss olympic association to host the winter youth olympics the ioc selected the host city for the winter youth olympics at the th ioc session in kuala lumpur malaysia on july which lausanne won history applicant city phase the headquarters of the international olympic committee in lausanne lausanne bid for the winter youth olympics was confirmed on july the city is where the international olympic committee is headquartered lausanne is also home to many sport federations the bid was formally put forward in august lausanne was signed youth olympic game candidature procedure on december previous bids the city of lausanne made several bids in the past lausanne bid to host the summer olympics in but lost to berlin the city again bid for the summer olympics which was awarded to london however those games were cancelled because of the second world war london hosted the summer olympics lausanne bid to host the summer olympics but lost to rome previous bids by other swiss cities st moritz hosted the and winter olympics st moritz unsuccessfully bid to host the and winter olympics and lost to garmisch partenkirchen and squaw valley respectively sion bid to host the and winter olympics but lost to denver salt lake city and turin respectively denver pulled out as host of the games and innsbruck ultimately hosted the games venues lausanne palais de beaulieu figure skating short track curling stade pierre de coubertin opening and closing ceremonies medal ceremonies unil epfl sport centre speed skating centre intercommunal de glace de malley hockey lausanne campus olympic village jura prémanon france ski jumping biathlon nordic combined le brassus cross country skiing alps leysin les mosses les diablerets villars sur ollon notes and references external links official website'},
#  {'score': 16.08534300905383,
#   'title': 'Wikipedia',
#   'para': 'claude quenneville is canadian sports commentator in quebec he served as the french language radio voice of the montreal canadiens of the national hockey league he began his career at the age of at radio station cjmt am in chicoutimi and was later hired by the cbc as an announcer in in he hosted weekly variety show called tempo he became well known by becoming the announcer for radio broadcasts for games played by the montreal canadiens from to he also hosted the popular show la soirée du hockey on src and been long time commentator on olympic events including weightlifting events at the olympics in montreal diving events at the olympics in los angeles gymnastics events at the olympics in seoul athletics in atlanta at the olympics and ice hockey in nagano at the winter olympics quenneville has also covered the commonwealth games of edmonton of edinburgh and victoria his work as sports commentator has earned him two gémeaux awards the first in for the best sports commentator and the second in with gilles tremblay for la soirée du hockey references'},
#  {'score': 16.063460868705345,
#   'title': 'Wikipedia',
#   'para': 'five cities made the shortlist with their bids to host the summer olympics formally known as games of the xxviii olympiad which were awarded to athens on september the other shortlisted cities were rome cape town stockholm and buenos aires final selection in the first round of voting buenos aires and cape town tied with the lowest number of votes round two was therefore tie breaker round between the two cities with buenos aires being eliminated stockholm was the next city to be eliminated followed by cape town the final round saw athens receive enough votes to defeat rome and win the right to host the summer olympics official voting results athens was the leader in all rounds of voting except in round which was tie breaker due to first round tie between cape town and buenos aires cape town won that round over buenos aires before losing out in the th round host city election ballot results city country noc round run off round round round athens rome cape town stockholm buenos aires bidding cities candidate cities the colosseum one of rome most famous landmarks the acropolis of athens logolink city country national olympic committee result px athens hellenic olympic committee hoc winner the city of athens greece submitted bid for the games and won the election in the final round of voting defeating rome athens previously hosted the first modern olympic games in and bid for the summer olympics which were awarded to london but cancelled due to world war ii and the summer olympics athens campaign logo is represented by watercolor version of an olympic cauldron with the flame shaped as capital rome italian national olympic committee coni first runner up the city of rome italy submitted bid for the games and lost the election in the final round of voting being defeated by athens rome was previously awarded the summer olympics but the eruption of mount vesuvius forced the italians to return the games to the ioc and passed the honors to london it would have been the second time rome hosted the games after the summer olympics rome also bid for the the cancelled games and was recently candidate city for the summer olympics but withdrew its bid two years after rome lost their bid turin was awarded the winter olympics rome campaign logo depicts an stylized version of coloseum backgrounded by the sun cape town south african sports confederation and olympic committee sascoc second runner up the city of cape town south africa submitted bid for the games and received the third most votes tying with buenos aires in the first round of voting and winning the run off cape town never hosted the summer olympics or bid before it was africa first bid since alexandria egypt failed its bids to host the cancelled summer olympics and the summer olympics both of which were awarded to berlin had cape town won the rights to host the olympic games it would have been the first olympic games in the continent of africa south africa was awarded the fifa world cup on may and cape town was one of the host cities cape town campaign logo consists of an stylized map of africa colored with the colors of the olympic rings which is formed around the location of cape town in the south of the continent stockholm swedish olympic committee sok third runner up the city of stockholm sweden submitted bid for the games and was eliminated in the third round of voting stockholm previously hosted the summer olympics as well as co hosted the summer olympics with melbourne stockholm campaign logo depicts the statue man and pegasus located at millesgården just outside stockholm its hopes were ruined when sports arenas in stockholm and göteborg were damaged by explosive bombs and arson attacks by mats hinze px buenos aires argentine olympic committee coa fourth runner up the city of buenos aires argentina submitted bid for the games and was eliminated in run off against cape town since both cities tied in the first round of voting buenos aires never hosted the summer olympic ...
#  {'score': 16.02462937593157,
#   'title': 'Wikipedia',
#   'para': 'dundumwezi is modified word from its original dundumwenze which means male mountain is constituency in chief siachitema in the south west of kalomo district of southern province zambia it is an underdeveloped remote constituency that lacks infrastructure and basic necessities and is often ignored by the government it lacks roads hospitals schools and housing demographics dundumwezi is inhabited by the tonga people of zambia august election in dundumwezi constituents favored an independent candidate over the popular united party for national development upnd candidate in the august general election voters showed overwhelming support for the leading opposition party president hakainde hichilema while only voted for the ruling party president edgar lungu who had never visited the area until july the elections were marred by violence instigated by the ruling patriotic front pf party against supporters of the opposition parties the counting process took three days the result was called into question by many opposition parties they accused the ruling party of delaying the release of the result granting election server access to foreign it specialists with connections to the ruling party disposing of opposition party ballot papers that were discovered in bin having pre marked ballot papers and allowing unverified ballot papers to be counted the area had been visited by sitting president once in and ignored thereafter following the visit of his excellence mr edgar lungu this year he has recognized and respected the cry of the people to develop dundumwezi the president is committed and has since included it in the national development plan despite having received few votes from the area tourism has also been extended in dundumwezi as development takes off references external links'},
#  {'score': 16.009292789330587,
#   'title': 'Wikipedia',
#   'para': 'communist party congress could refer to ruling or former ruling communist parties congress of the socialist unity party of germany national congress of the communist party of vietnam national congress of the communist party of china congress of the romanian communist party congress of the communist party of the soviet union congresses of the communist party of lithuania non ruling communist party congresses congresses of the communist party of brazil'},
#  {'score': 15.943671862094131,
#   'title': 'Wikipedia',
#   'para': 'there were six bids initially submitted for the summer olympics tokyo was ultimately elected as the host city at the th ioc session in buenos aires argentina on september bidding process the olympic bidding process begins with the submission of city application to the international olympic committee ioc by its national olympic committee noc and ends with the election of the host city by the members of the ioc during an ordinary session the process is governed by the olympic charter as stated in chapter rule since the process has consisted of two phases during the first phase which begins immediately after the bid submission deadline the applicant cities are required to answer questionnaire covering themes of importance to successful games organization this information allows the ioc to analyze the cities hosting capacities and the strengths and weaknesses of their plans following detailed study of the submitted questionnaires and ensuing reports the ioc executive board selects the cities that are qualified to proceed to the next phase the second phase is the true candidature stage the accepted applicant cities from now on referred to as candidate cities are required to submit second questionnaire in the form of an extended more detailed candidature file these files are carefully studied by the ioc evaluation commission group composed of ioc members representatives of international sport federations nocs athletes the international paralympic committee and international experts in various fields it is chaired by sir craig reedie the members of the evaluation commission then make four day inspection visits to each of the candidate cities where they check the proposed venues and are briefed about details of the themes covered in the candidature file the evaluation commission communicates the results of its inspections in report sent to the ioc members up to one month before the electing ioc session the ioc session in which host city is elected takes place in country that did not submit an application to stage the olympics the election is made by the assembled active ioc members excluding honorary and honor members each possessing one vote members from countries that have city taking part in the election cannot vote while the city is in the running the voting is conducted in succession of rounds until one bid achieves an absolute majority of votes if this does not happen in the first round the bid with the fewest votes is eliminated and another voting round begins in the case of tie for the lowest number of votes special runoff vote is carried out with the winner proceeding to the next round after each round the eliminated bid is announced following the announcement of the host city the successful bid delegation signs the host city contract with the ioc which delegates the of the games organisation to the city and respective noc bidding timeline the timeline of the host city selection process was approved by the international olympic committee ioc executive board as follows may ioc sent letters inviting the national olympic committees nocs to submit bids july and august ioc asked for nocs to submit letters regarding compliance with the world anti doping agency code by july the ioc also requested submissions of proposed dates if countries want to stage the games outside the normal period set by the ioc july to august the ioc responded to nocs on these points by the end of august september deadline to submit the names of cities interested in hosting the summer games september ioc confirmed that they had received six bids november ioc held an information seminar for applicants december ioc announced the drawing lots order of applicant cities february application files and guarantee letters submitted to the ioc may ioc executive board in quebec city decided which cities were to be approved as official candidate cities july august olympic games observers programme at the games of the xxx olympiad in london november olympic ga ...
#  {'score': 15.932951385563095,
#   'title': 'Wikipedia',
# ...
#  {'score': 15.444647559845158,
#   'title': 'Wikipedia',
#   'para': 'the popular action of equatorial guinea is political party in the equatorial guinea it is led by carmelo mba bacalé it is currently one of many opposition parties in the country banned by the ruling party the democratic party of equatorial guinea the ruling party since despite being an illegal party bacalé gained of the country vote for the ap in the equatoguinean presidential election references'},
#  {'score': 15.43243148059007,
#   'title': 'Wikipedia',
#   'para': 'the winter olympics which would have been officially known as the were to have been celebrated from to february in sapporo japan but the games were eventually cancelled due to the onset of world war ii sapporo subsequently hosted the winter olympics history sapporo was selected to be the host of the fifth edition of the winter olympics scheduled february but japan gave the games back to the ioc in july after the outbreak of the second sino japanese war in the ioc then decided to give the winter olympics to st moritz switzerland which had hosted it in however the swiss organizers believed that ski instructors should be considered professionals the ioc was not of that mind and the games were withdrawn again in the spring of the ioc gave the winter olympics now scheduled for february to garmisch partenkirchen germany where the previous games had been held five months later on september germany invaded poland igniting world war ii and the winter games were cancelled in november likewise the games awarded in to cortina ampezzo italy were cancelled in st moritz held the first post war games in while cortina ampezzo hosted in germany has not hosted the winter olympics since on july munich lost to pyeongchang south korea to host the winter games see also external links planned program for the winter olympics in sapporo and garmisch partenkirchen'},
#  {'score': 15.390881429605596,
#   'title': 'Wikipedia',
#   'para': 'olimpiysky pool moscow as seen in the swimming pool at the olimpiysky sports complex is covered swimming centre in moscow russia the venue built for the summer olympics makes up the olimpiysky sports complex architectural ensemble together with the olimpiysky arena during the olympics it hosted the swimming diving water polo and the swimming part of the modern pentathlon events it also hosted short course world championships the venue consists of swimming pool with capacity for spectators separated by an acoustic partition from the diving pool with capacity for spectators see also olympic pool at the luzhniki olympic complex references external links official website of the olympiisky sports complex'},
#  {'score': 15.38801518613207,
#   'title': 'Wikipedia',
#   'para': 'guadalajara was bid by the city of guadalajara and the comité olímpico mexicano to host the summer youth olympics history on february guadalajara bid was selected over monterrey bid to bid to host the summer youth olympics by an inner voting from the mexico national olympic committee it was reported in august that the bid may be in danger due to the debt created by the pan american games guadalajara failed to become candidate city for the games when the ioc selected the candidate cities on february buenos aires was ultimately elected as the host city of the summer youth olympic games on july previous bids from other mexican cities the rotonda de los jaliscienses ilustres at night guadalajara was elected previously to bid to host the summer youth olympics but withdrew their bid following this report nanjing was ultimately awarded the games mexico city hosted the summer olympic games in mexico city made two bids prior to their bid they bid for the and summer olympics but lost to melbourne and rome respectively guadalajara had previously hosted the pan american games and bid for the world aquatics championships but withdrew the championships were awarded to budapest see also monterrey bid for the summer youth olympics mexico at the olympics bids for the summer youth olympics references'},
#  {'score': 15.384197671936011,
#   'title': 'Wikipedia',
#   'para': 'the popular union of equatorial guinea is political party in the equatorial guinea it is led by daniel martinez ayecaba the party was originally banned by the ruling democratic party of equatorial guinea the ruling party since but was legalized in may the up candidate archivaldo montelo biribé gained of the country vote in the equatoguinean presidential election references'},
#  {'score': 15.375723900710383,
#   'title': 'Wikipedia',
#   'para': 'birkebeineren ski stadium is cross country skiing and biathlon venue located in lillehammer norway situated from the town center and at above mean sea level it has two stadium areas one for cross country and one for biathlon the former has capacity for spectators and the latter for the venue was built for the winter olympics costing million norwegian krone nok it was subsequently used by the winter paralympics for paralympic nordic skiing and paralympic biathlon after the games ownership was transferred to the municipal lillehammer olympiapark the venue has since been used for one biathlon world cup three fis cross country world cup and nine fis nordic combined world cup tournaments the latter with the ski jumping competition taking place at the nearby lysgårdsbakkene ski jumping arena birkebeineren hosted the winter youth olympics construction the location of the venue was decided in january following lillehammer successful bid to host the winter olympics construction was managed by the lillehammer olympic organizing committee looc architects were arkitekter and the main consultant was tonning lieng construction started in early before planning was completed and lasted until the construction work was subcontracted to several companies landscaping was completed in the facilities used concrete and wood as the main materials the stadium included of temporary buildings building converted to riding center after the olympics and tent the land around the venue is swamp and most of the surface soil had to be removed and replaced with harder earth the soil was used as fertilizer or fill in other parts of the arena creek had to be bypassed with long pipe the arena is also so flat that drainage system had to be installed after the olympics four temporary overpasses were removed construction of the tracks was done to minimize the impact on the forest the venue cost nok million and was inaugurated on november with an international biathlon competition in december the looc stated that they wanted to upgrade the stadium spectator capacity but that the transport systems would not allow more people in the stadium had world cup tournaments in biathlon and cross country skiing as trial before the olympics during several events the computer system controlling the scoreboard and television scores collapsed president johan baumann of the norwegian ski federation criticized the venue and demanded that new stadium be built he stated that the stadium had been built to optimize television pictures and that it had insufficient facilities for the spectators in particular he criticized the fact that the spectators were too far away from the skiers and the lack of television screen and more scoreboards in may the looc announced that the stadium would be expanded for another people before the olympics on september the ownership of the venue was transferred from the looc to lillehammer municipality via the subsidiary lillehammer olympiavekst which later changed its name to lillehammer olympiapark in october the forest along the tracks were partially cleared to allow spectators without tickets to watch the events facilities the arena covers an area of and is from the town center for the olympics of cross country tracks and of biathlon tracks were built there are two stadiums one for cross country skiing and one for biathlon the former has spectator capacity for while the latter has capacity for in addition up to people watched the events the trackside during the olympics permanent buildings include finishing house for biathlon finishing house for cross country plant room the cross country stadium is long while the biathlon stadium is long the biathlon stadium has shooting stations the facility has kva transformer with an additional transformer used during the olympics critical systems such as computers and time keeping equipment have an uninterruptible power supply as recreational venue birkebeineren connects to of skiing tracks including lighted  ...
#  {'score': 15.35143907463622,
#   'title': 'Wikipedia',
#   'para': 'right start at the cresta run in st moritz host of the skeleton events for both the and winter olympics turn at the whistler sliding centre in for the winter olympics in vancouver the venue hosted the skeleton events for the winter olympics there have been six venues that have been or will be used for skeleton when the winter olympics were in st moritz they took place at the cresta run for both and since being re introduced at the winter olympics skeleton has shared the same venue with the other sliding sports of bobsleigh and luge games venue other sports hosted at venue for those games capacity ref st moritz cresta run none not listed st moritz cresta run none not listed salt lake city utah olympic park includes bobsleigh luge and skeleton track bobsleigh luge nordic combined ski jumping ski jumping ski jumping bobsleigh luge skeleton turin cesana pariol bobsleigh luge vancouver the whistler sliding centre bobsleigh luge sochi sliding center sanki bobsleigh luge pyeongchang alpensia sliding centre bobsleigh luge references'},
#  {'score': 15.33618124931852,
#   'title': 'Wikipedia',
#   'para': 'aerial view of the current bobsleigh luge and skeleton track at the winter games this was where the luge track was located the bobsleigh track used for the and winter olympics no longer in use is seen at the lower part of the picture for the winter olympics in lake placid new york united states total of seven sports venues were used all five of the venues used for the winter olympics were also used at the winter games with adjustments these adjustments included electronic scoreboards increased refrigeration and the addition of separate luge track this was the last winter olympics where there were separate bobsleigh and luge tracks the closest finish in olympic history in cross country skiing led skiing officials to time future events in hundredths of second rather than tenths of second this would also apply to biathlon events eric heiden of the united states won five gold medals at the speed skating oval while the miracle on ice took place between americans and soviets at the olympic center in the late the luge track was demolished and new combination track was constructed in time for the only winter goodwill games held the sliding venue was named to the american national register of historical places in february venues map of the venues in lake placid venue sports capacity ref intervales ski hill nordic combined ski jumping ski jumping lake placid equestrian stadium opening ceremonies lake placid olympic sports complex cross country biathlon center biathlon cross country skiing nordic combined cross country skiing not listed mt van hoevenberg bob and luge run bobsleigh luge separate tracks bobsleigh olympic center arena figure skating ice hockey olympic arena james sheffield speed skating oval speed skating whiteface mountain alpine skiing not listed before the olympics lake placid hosted the winter olympics in with all five venues used for those games being used for the winter olympics the city made four unsuccessful bids for the winter olympics in and before being awarded the winter olympics by the international olympic committee ioc in between the winter games and the winter games lake placid played host to winter sports championships the first time many of them were held outside of europe after the games the speedskating oval hosted the world allround speed skating championships for men the bob run hosted the fibt world championships in and in the fis nordic world ski championships took place at the ski jump used for the games for the ski jumping and the ski jumping part of the nordic combined event biathlon held their first world championships outside of europe at lake placid in when lake placid was awarded the winter games in venue adjustments were needed for the alpine skiing events snow making equipment was used this was used to make of man made snow to cover all of the trails used for the events six new ski lifts and electronic timing scoring systems were also constructed for the nordic skiing events cross country skiing nordic combined ski jumping total of event officials were sent as observers to the world championships in lahti finland to understand the venue needs for the games for the km race total of was purchased and trail system was created that involved tree clearing man made snow was also applied for the cross country skiing trail races over km in length were modified to meet the snow requirements as defined by the international ski federation an electronic scoreboard was installed for the cross country skiing events this information was passed onto organizers for the winter olympics in sarajevo two new ski jumps were constructed the jump was constructed between may and december construction for the jump also started in may but was not done until the february test event to construction delays caused by the bankruptcy of the steel contractor biathlon used trails similar to cross country skiing though separate finish area was used protective shooting area of was built for the competition of for sho ...
#  {'score': 15.295942665184704,
#   'title': 'Wikipedia',
#   'para': 'is mountain located in yamanouchi nagano japan for the winter olympics it hosted the alpine skiing slalom and snowboarding giant slalom events during the games the mountain suffered mild earthquake that registered on the richter magnitude scale but the skiing events continued references winter olympics official report volume pp poor skiing conditions nothing new to whistler february toronto observer article accessed september shinmai co jp winter olympics venue profile'},
#  {'score': 15.244994561315828,
#   'title': 'Wikipedia',
#   'para': 'the camp olímpic de tir amb arc was temporary venue located in barcelona it hosted the archery competitions for the summer olympics it was located in site at the ronda de dalt next to the pavelló de la vall hebron in the barcelona district of horta guinardó after the olympics it was remodelled into ciutat esportiva municipal vall hebron teixonera which consists of two football soccer fields rugby field and an annexe service area references summer olympics official report volume pp'},
#  {'score': 15.21769728323561,
#   'title': 'Wikipedia',
#   'para': 'the hon clyde mascoll is politician from barbados he is former leader of the democratic labour party dlp in mascoll unsuccessfully led the party in an election against the ruling barbados labour party blp however after internal disagreement within the dlp mascoll crossed the floor to become member of the ruling blp in becoming minister of state in the ministry of finance he was defeated in his st michael north west constituency by the dlp christopher sinckler in the january general election receiving of the vote references'}]

# %%
from IPython.display import FileLink

# Display a download link in the notebook output
display(FileLink("cache/docs.json"))
# Out:
# /kaggle/working/cache/docs.json

# %%
# !zip -r output.zip cache/
from IPython.display import FileLink
display(FileLink("output.zip"))
# Out:
#   adding: cache/ (stored 0%)
#   adding: cache/docs.json (deflated 71%)
#   adding: cache/sents.json (deflated 70%)
# /kaggle/working/output.zip

# %%
import json

data = {"foo": 42, "bar": [1, 2, 3]}

# Write to the working directory
out_path = "/kaggle/working/results.json"
with open(out_path, "w") as f:
    json.dump(data, f, indent=2)

print(f"Saved results to {out_path}")
# Out:
# Saved results to /kaggle/working/results.json

# %% [markdown]
# import os
# import json
#
# def find_json_file(filename, search_dir="."):
#     """
#     Recursively search for `filename` under `search_dir`.
#     Returns the first full path found, or None if not present.
#     """
#     for root, _, files in os.walk(search_dir):
#         if filename in files:
#             return os.path.join(root, filename)
#     return None
#
# # Example usage:
# target = "docs.json"
# path = find_json_file(target, search_dir=".")
# if path is None:
#     raise FileNotFoundError(f"Could not find {target} under current folder")
# print(f"Found at: {path}")
#
# # Now load it:
# with open(path, "r", encoding="utf-8") as f:
#     data = json.load(f)
#
# # `data` now holds your JSON contents; for example:
# print(data[:2])  # print first two entries if it's a list of objects

# %%
# docs path : ./cache/docs.json

# %% [markdown]
# import os
# import json
#
# CACHE_DIR = "cache"
# docs_path = os.path.join(CACHE_DIR, "docs.json")
#
# # 1) Verify the file exists and isn’t empty
# if not os.path.exists(docs_path):
#     raise FileNotFoundError(f"{docs_path} not found. Run the Topic Retriever first.")
# if os.path.getsize(docs_path) == 0:
#     raise RuntimeError(f"{docs_path} is empty. Delete it and rerun the Topic Retriever.")
#
# # 2) Try to load, with fallback
# try:
#     with open(docs_path, "r", encoding="utf-8") as f:
#         docs_data = json.load(f)
#     # Convert back to your in-memory format
#     docs = [(d["score"], d["title"], d["para"]) for d in docs_data]
# except json.JSONDecodeError:
#     # If parsing fails, delete the bad cache and recompute
#     os.remove(docs_path)
#     print(f"⚠️ Cache corrupted, removed {docs_path}. Please rerun the Topic Retriever.")
#     raise

# %%
docs
# Out:
# [(17.741650576283966,
#   'Wikipedia',
#   'for the winter olympics in st moritz switzerland total of eight sports venues were used the five venues used for the winter olympics were reused for these games three new venues were added for alpine skiing which had been added to the winter olympics program twelve years earlier in garmisch partenkirchen germany allied occupied germany during the games as of the bob run continues to be used for bobsleigh and the cresta run for skeleton while alpine skiing remains popular in st moritz venues venue sports capacity ref around the hills of st moritz cross country skiing nordic combined cross country skiing not listed cresta run skeleton not listed kulm ice hockey not listed olympiaschanze st moritz ski jumping nordic combined ski jumping not listed olympic stadium opening closing ceremonies figure skating ice hockey final speed skating not listed piz nair alpine skiing not listed st moritz celerina olympic bobrun bobsleigh not listed suvretta ice hockey not listed before the olympics st moritz hosted the winter olympics previously in all five venues from those games were reused for the winter olympics st moritz hosted the fibt world championships in four man four man two man two man and switzerland itself hosted the ice hockey world championships twice in between the and games doing so in and though neither took place in st moritz as an alpine skiing venue st moritz hosted the fis alpine world ski championships in during the olympics midway through the second run of the bobsleigh four man event water pipe burst which halted competition they still completed all four runs of the event after the olympics the ski jump was renovated in to get it to point of it closed in the bob run has hosted the fibt world championships sixteen more times since the games most recently in st moritz hosted its first recorded alpine skiing world cup event in the city hosted the alpine skiing world championships in and references'),
#  (17.518419295818905,
#   'Wikipedia',
#   'right horse guards parade hosted the beach volleyball events at the summer olympics in london copacabana stadium hosted the volleyball preliminaries for the summer olympics in rio de janeiro for the summer olympics there are venues that have been or will be used for beach volleyball beach location games events notes atlanta beach clayton county international park jonesboro clayton county georgia usa beach volleyball at the summer olympics artificial beach bondi beach bondi beach waverley council eastern suburbs sydney new south wales australia beach volleyball at the summer olympics ocean coast beach faliro olympic beach volleyball centre faliro coastal zone olympic complex faliro athens greece beach volleyball at the summer olympics artificial beach chaoyang park beach volleyball ground chaoyang park chaoyang district beijing china beach volleyball at the summer olympics artificial beach with sand imported from hainan horse guards parade whitehall london england uk beach volleyball at the summer olympics artificial beach on royal parade grounds copacabana beach copacabana stadium copacabana beach copacabana rio de janeiro brazil beach volleyball at the summer olympics ocean coast beach shiokaze park stadium shiokaze park tokyo waterfront tokyo kanto japan beach volleyball at the summer olympics see also list of olympic venues in volleyball references'),
#  (17.29930767868344,
#   'Wikipedia',
#   'kazakoshi park arena is an indoor arena located in karuizawa nagano japan constructed in with an opening ceremony taking place in it hosted the curling competition for the winter olympics in nagano because it was in karuizawa the town became the first venue to host events at both the summer and winter olympics at the summer olympics in tokyo karuizawa hosted the equestrian events references winter olympics official report volume pp icing org profile of the venue shinmai co jp winter olympics profile of the arena'),
#  (17.213456148257933,
#   'Wikipedia',
#   'the human rights party or kanakpak sethi manus is cambodian political party founded on july led by kem sokha critics allege that its foundation is meant to weaken opposition parties and is driven by the ruling party this sentiment however seems to be driven by the ruling party themselves as kem sokha has long been very vocal critic of the ruling cpp party at the time of its foundation the party claimed to have between and members nationwide human rights party is the first party in cambodia to adopt the check and balance system changing the culture of one man ruling parties which most parties in cambodia adopt it is also the first party in cambodia to have its major leaders elected in its convention its popularity has been dramatically increasing in cambodia especially in the countryside in the july parliamentary elections the ruling party won landslide majority and the human rights party took third place in it merged with the sam rainsy party to form the cambodia national rescue party electoral performance general election election leader votes seats position government kem sokha rd communal election election leader votes communes councillors position kem sokha rd references external links hrp website khmer french english habeas corpus net pro justice and democracy web publishes page in english and spanish on cambodia'),
#  (17.069092988406577,
#   'Wikipedia',
#   'the adler arena trade and exhibition center адлер арена is an seat speed skating oval in the olympic park sochi russia it opened in and looks like an iceberg or ice fault the center hosted the speed skating events at the winter olympics original plans for after the olympics were for the adler arena to be turned into an exhibition center it cost million to build the venue including the temporary works for the olympics before the olympics it hosted the russian speed skating championships in december and the world single distance speed skating championships from to march construction crystal face theme is supported by angular walls and triangular stained glass windows the gray and white color of the building enhances this impression the walls along the sides of the skating rink are made transparent so that spectators can look outside the skating center is designed to make the utmost use of local natural features track records men distance skater time date event ronald mulder february winter olympics stefan groothuis february winter olympics zbigniew bródka february winter olympics ivan skobrev february test competition sven kramer february winter olympics jorrit bergsma february winter olympics teampursuit laps jan blokhuijsensven kramerkoen verweij february winter olympics combination skater points date match michel mulder february winter olympics sprint dmitry lobkov december national championship all round ivan skobrev december national championship women distance skater time date event lee sang hwa february winter olympics zhang hong february winter olympics jorien ter mors february winter olympics ireen wüst february winter olympics martina sáblíková february winter olympics teampursuit laps marrit leenstrajorien ter morsireen wüst february winter olympics combination skater points date match lee sang hwa february winter olympics sprint olga fatkulina december national championship all round yekaterina shikhova december national championship source www info other uses the skating centre hosted the world robot olympiad russia hosted their fed cup world group semifinals tie at the adler arena references external links adler arena on www info'),
#  (16.649201347941414,
#   'Wikipedia',
#   'london hosted the olympic games in and the summer olympics made london the first city to have hosted the modern games of three olympiads london is the only city in the united kingdom to have ever hosted the olympics the united states is the only country to have hosted summer olympics on more occasions than the uk also london is the only city to have bid more than once and still hold record british participation in olympic events both as competitor and as host is the responsibility of the british olympic association summer olympics london olympics the summer olympics the games of the iv olympiad were the fifth modern olympic games and the third to be hosted outside of athens greece the international olympic committee considers them the fourth olympic games discounting the intercalated summer olympics the olympic games were scheduled to take place in rome but the eruption of mount vesuvius on april required the italian government to redirect funds away from the olympics the events took place between april and october with nations participating in events the british team easily topped the unofficial medal count finishing with three times as many medals as the second place united states summer olympics the summer olympics the games of the xiii olympiad were scheduled to be held in london awarded in they were however cancelled due to world war ii these games would have celebrated the th anniversary of the modern olympiad summer olympics the summer olympics the games of the xiv olympiad were the first to be held after world war ii with the summer olympics having been cancelled due to the war showing collective unity after the war nations competed in different events between july and august germany and japan were not invited to the games due to security reasons unlike the previous time the uk hosted the olympics the british athletes did not have high medal count finishing th in the unofficial medal count with only medals summer olympics the summer olympics the games of the xxx olympiad took place between july and august the london olympic bid was announced as the winner of the bidding process on july following unsuccessful bid attempts for previous olympics by manchester and birmingham team gb finished rd with gold medals and total medals representing their best medal haul since london first hosted the olympics in summer paralympics the summer paralympics were the fourteenth paralympics and took place between august and september at the summer olympics venues in london external links london olympic games official website london olympic games information portal commentary on olympic park'),
#  (16.59422882944778,
#   'Wikipedia',
#   'snow harp is cross country skiing venue located in hakuba nagano japan for the winter olympics the venue hosted the cross country skiing and the cross country skiing portion of the nordic combined events completed in test events were held in the venues consisted of three courses that were and in length respectively it hosted events during the games the most of any venue references winter olympics official report volume pp hakuba nagano venue profile shinmai co jp winter olympics profile snowjapan com profile'),
#  (16.554317816813846,
#   'Wikipedia',
#   'paris has hosted several olympiads and and will host in paris will be the second city in the modern games to have hosted three olympiads when paris hosts the summer olympics the other being london the french national olympic and sports committee oversees france interests in the olympics summer olympics paris summer olympics the summer olympics the games of the ii olympiad were the third modern olympics and the inaugural hosted outside of athens greece the international olympic committee considers them the second olympics discounting the intercalated summer olympics the summer olympics were held simultaneously with the world fair the events took place between may and october with nations participating in events the french team topped the unofficial medal count finishing with three times as many medals as the second place united states while fielding ten times as many athletes summer olympics the summer olympics the games of the viii olympiad were the second to be held after world war showing collective unity after the war nations competed in different events between may and july germany was not invited to the games due to security reasons unlike the previous time france hosted the olympics the french athletes did not have high medal count finishing rd in the unofficial medal count with only medals summer olympics the summer olympics the games of the xxxiii olympiad will take place from july to august the paris olympic bid was announced as the winner of the bidding process on september following unsuccessful bid attempts for previous olympiads summer paralympics the summer paralympics will be the seventeenth paralympics and will take place between august and september at the summer olympics venues in paris external links paris olympic games official website'),
#  (16.49412079690418,
#   'Wikipedia',
#   'los angeles hosted the olympic games in and and will host again in the summer olympics made los angeles the third city to have hosted the modern games of three olympiads los angeles will be the only city in the united states to have ever hosted the olympics three times american participation in olympic events both as competitor and as host is the responsibility of the united states olympic committee summer olympics the summer olympics the games of the olympiad were the eleventh modern olympic games and the eighth to be hosted outside of athens greece the international olympic committee considers them the tenth olympic games discounting the intercalated summer olympics the events took place between july and august with nations participating in events summer olympics the summer olympics the games of the xxiii olympiad was held between july and august the soviet union and its satellites boycotted the games summer olympics the summer olympics games of the xxxiiv olympiad will take place between july and august summer paralympics the summer paralympics will be the eighteen paralympic games and will take place in los angeles for the first time external links la'),
#  (16.373430619215696,
#   'Wikipedia',
#   'the faliro sports pavilion arena which is part of the faliro coastal zone olympic complex is an indoor arena in palaio faliro in athens greece it is nicknamed the little peace and friendship stadium due to its similarity in design and close proximity to the peace and friendship stadium it was the site of the athens summer olympics preliminary matches of handball as well as the taekwondo competition the arena seats for handball matches of olympics though only seats were made publicly available during the olympics history the arena was completed on december and it officially opened on august shortly before the olympics began in june the arena hosted the th mad video music awards held by mad tv and hosted by themis georgantas the prodigy had sold out concert event at the arena tiesto performed at the arena during his kaleidoscope world tour the arena is also known as long time venue for holiday on ice shows it also hosted the greek legends event by riot games league of legends lan tournament in june and it hosted the finals of the league of legends greek championship season in the th and january co organized by riot games ast and inspot references external links summer olympics official report volume pp gr profile faliro arena stadia gr'),
#  (16.3471222533474,
#   'Wikipedia',
#   'for the summer olympics there have been fourteen olympic sports that have been discontinued from the program as of the summer olympics in london for the summer olympics in rio de janeiro golf and rugby union were reinstated as olympic sports though the latter was as rugby sevens as of there have been eight baseball two basque pelota one cricket one croquet two golf one jeu de paume two lacrosse five polo one racquets five rugby union fifteen side four softball five tug of war and one water motorsports venues used for the summer olympics baseball and softball now governed by single international federation and thus treated by the international olympic committee ioc as two disciplines of single sport will be part of the summer olympics program in tokyo the sports are not included in paris plan for the games but are part of los angeles plan for the games baseball right atlanta fulton county stadium hosted the baseball events for the summer olympics games venue other sports hosted at venue for those games capacity ref los angeles dodger stadium demonstration none seoul jamsil baseball stadium demonstration none barcelona camp municipal de beisbol de viladecans none hospitalet de llobregat baseball stadium final none atlanta atlanta fulton county stadium none sydney blacktown olympic park softball sydney baseball stadium final modern pentathlon riding running athens olympic baseball centre none beijing wukesong baseball field none basque pelota right games venue other sports hosted at venue for those games capacity ref paris neuilly sur seine none not listed barcelona pavelló de la vall hebron demonstration volleyball volleyball basque pelota cricket right vélodrome de vincennes hosted the cricket matches at the summer olympics in paris games venue other sports hosted at venues for those games capacity ref paris vélodrome de vincennes cycling football gymnastics rugby union not listed croquet right games venue other sports hosted at venue for those games capacity ref paris bois de boulogne polo tug of war not listed jeu de paume right queen club hosted the jeu de paume events for the summer olympics in london games venue other sports hosted at venue for those games capacity ref london queen club racquets not listed lacrosse right games venue other sports hosted at venue for those games capacity ref st louis francis field archery athletics cycling football gymnastics roque tennis tug of war weightlifting wrestling london white city stadium archery athletics cycling track diving field hockey football gymnastics rugby union swimming tug of war water polo final wrestling polo right ostend hosted the polo events for the summer olympics in antwerp games venue other sports hosted at venue for those games capacity ref paris bois de boulogne croquet tug of war not listed london hurlingham club none not listed antwerp ostend sailing not listed paris bagatelle none saint cloud none berlin mayfield equestrian dressage racquets right games venue other sports hosted at venues for those games capacity ref london queen club jeu de paume not listed roque right games venue other sports hosted at venue for those games capacity ref st louis francis field archery athletics cycling football gymnastics lacrosse tennis tug of war weightlifting and wrestling rugby union fifteen side softball right blacktown olympic stadium hosted the softball events for the summer olympics in sydney games venue other sports hosted at venue for those games capacity ref atlanta golden park none sydney blacktown olympic park baseball athens olympic softball stadium none not listed beijing fengtai softball field none tug of war right games venue other sports hosted at venue for those games capacity ref paris bois de boulogne croquet polo not listed st louis francis field archery athletics cycling football gymnastics lacrosse roque tennis weightlifting and wrestling london white city stadium archery athletics cycling track diving field hockey football gymnastics lacrosse rug ...
#  (16.335045140998613,
#   'Wikipedia',
#   'poznań was bid by the city of poznań and the polish olympic committee to host the summer youth olympics poznan withdrew their bid on october for financial reasons history poznań was revealed to be one of the bidding cities for the summer youth olympics when the ioc announced who the applicants were on march poznań was one of the eight cities that hosted games during the uefa euro championship the stadion miejski hosted three matches during the championship poznań in last few years was host city of such sport events as the men indoor hockey world cup in the city hosted the academic canoeing world cup academic basketball world cup european male basketball cup and the european athletic cup for vets in the city hosted the academic futsal world cup and was one of the host cities for the uefa european under football championship on october the city council rejected the proposed budget for the bid there was lack of financial guarantees from the city organizer and the city withdrew its bid buenos aires was ultimately elected as the host city of the summer youth olympic games on july previous bids view of poznań old town poznań bid to host the summer youth olympics but lost to nanjing by only five votes they bid to host the summer youth olympics but failed to become candidate those games were ultimately awarded to singapore previous bids by other polish cities zakopane bid to host the winter olympics but lost to turin see also poland at the olympics bids for the summer youth olympics references'),
#  (16.33118298523432,
#   'Wikipedia',
#   'piscines bernat picornell is swimming venue situated in the olympic ring in montjuïc barcelona the venue consists of three swimming pools indoor pool outdoor pool and pool for diving it hosted the swimming events synchronized swimming events the water polo final and the swimming part of the modern pentathlon event for the summer olympics the swimming pools are for public use and are open all year long history the venue named after the catalan swimmer and founder of the spanish swimming federation bernat picornell richier was built to host the european aquatics championships in refurbishment works began for the olympics the main changes were that the training pool was covered and that temporary grandstands were installed boosting the capacity to more than spectators since the olympics the outdoor swimming pool with capacity for spectators has hosted several spanish and catalan swimming championships as well as the synchronized swimming events for the world aquatics championships in it hosted the water polo events for the world aquatics championships since the city of barcelona repeated as host ten years later see also piscina municipal de montjuïc references summer olympics official report volume pp external links official site'),
#  (16.297272864156565,
#   'Wikipedia',
#   'for the winter olympics in albertville france total of thirteen sports venues were used val isère has been part of the alpine skiing world cup since the late while tignes served as host of the first freestyle world ski championships in most of the venues used were constructed between and mid with the test events taking place in late and early it was the last winter olympics with an outdoor speed skating rink which led to weather issues for three of the ten events three cross country skiing events were run in snowstorms while the men km biathlon was found to be too short the downhill events in alpine skiing were criticized for being too steep freestyle skiing made its official debut at these games with the men winner being stormed after his win while the women winner won her event in snow storm la plagne hosted the skeleton world championships in while val isère hosted the alpine world ski championships in venues venue sports capacity ref anneau de vitesse speed skating la halle de glace olympique figure skating short track speed skating la plagne bobsleigh luge not listed les arcs speed skiing demonstration not listed les menuires alpine skiing men slalom not listed les saisies biathlon cross country skiing méribel alpine skiing women méribel ice palace ice hockey patinoire olympique de pralognan la vanoise curling demonstration théâtre des cérémonies ceremonies opening closing tignes freestyle skiing not listed tremplin du praz nordic combined ski jumping jumping nordic combined cross country skiing val isère alpine skiing men downhill super giant slalom giant slalom and combined not listed before the olympics albertville is part of the rhône alpes region in france that had hosted the winter olympics twice with chamonix in and grenoble in jean claude killy the triple gold medalist in the men alpine skiing event at the grenoble games had become successful businessman when he suggested the idea of the winter olympics in december to michel barnier politician in the savoie department proposal was sent to the albertville town council six months later followed regional studies done during presentation and media operations for the bid took place from to its awarding in by the international olympic committee after five rounds of voting albertville was selected over sofia bulgaria falun sweden val isère had its first alpine skiing world cup events run in december the olympic test held there in december was won by winter olympics men downhill gold medalist leonhard stock of austria tignes hosted of the first fis freestyle world ski championships in february construction on most of the venues took place between and mid in time for the late and early test events during the olympics this was the last winter olympics in which speed skating was held outdoors as result weather played factor in three of the ten events run in the women on february the start of the event was delayed one hour the let the outdoor oval ice harden warm weather delayed the women event for an hour on the th the following day the men event was held in steady rain norway geir karlstad the gold medalist in the men commented in the post race press conference that didn like soft ice up to now but now do this led to the international skating union passing rule after the winter games stating that all olympic speed skating competitions should be held indoors which it has been since the winter olympics in lillehammer for the alpine skiing downhill courses complaints were given that the courses were too steep on the men side the complaints from downhill skiers that it was more like super giant slalom course rather than classical downhill course the women course was long and had the steepest vertical drop ever at further making the women downhill challenge was an impending snowstorm that forced race officials to move up the start time and send the skiers out at shorter than usual intervals an intermittent fog also set in during the women downhill cross country skiing had sno ...
#  (16.220804878361456,
#   'Wikipedia',
#   'stadio olimpico di torino turin olympic stadium as football venue in for the winter olympics it hosted the opening and closing ceremonies for the winter olympics in turin italy total of fifteen sports venues were used venue construction ran from to cesana pariol had to have turns and modified following the luge world cup in january but they were not cleared out until october winds postponed the nordic combined team event for day many of the venues served as host for the winter universidade the following year venues city venue sports capacity ref oval lingotto speed skating palavela figure skating short track speed skating palasport olimpico ice hockey final stadio olimpico grande torino ceremonies opening closing torino esposizioni ice hockey mountain venue sports capacity ref bardonecchia snowboarding cesana pariol bobsleigh luge skeleton cesana san sicario biathlon pinerolo palaghiaccio curling pragelato nordic combined ski jumping ski jumping pragelato plan cross country skiing nordic combined cross country skiing san sicario fraiteve alpine skiing women combined downhill downhill super sauze oulx jouvencaux freestyle skiing sestriere borgata alpine skiing men combined downhill downhill super sestriere colle alpine skiing combined slalom giant slalom slalom before the olympics palavela during the winter olympics the venue hosted the figure skating and short track speed skating events during those games stadio olimpico in was known as stadio benito mussolini for the fifa world cup that took place that year the stadium hosted two matches including the quarterfinal match between czechoslovakia and switzerland turin was selected by the italian olympic committee to be selected to host the winter olympics in march it was awarded the winter olympics on june cesana pariol construction began in and was completed in after luge world cup test event in january that was abandoned to accidents this led to modifications of turns and and retest of the track that was approved by the international luge federation fil in october oval lingotto opened on december palavela constructed in was modified for the games to host figure skating and short track speed skating events san sicario fraiteve hosted an alpine skiing world cup in february and was modified to make the women super event more challenging torino esposizinoi was constructed in and refurbished in time for the games to host the preliminary ice hockey matches venues were selected between may and the summer of construction of the venues ran between the summers of and the venues were turned over for use of the games between the summer of and february new construction included cesana pariol cesana san sicario pragelato pragelato plan and sauze ouix jouvencaux while the other venues used were refurbished or expanded sustainability efforts were applied on all venues but the most noted in the olympics report were cesana pariol and pragelato plan the most expensive venue construction in the mountain area was cesana pariol at million while the most expensive city venue used for competition in the city area was oval lingotto at million during the olympics picture of turns through right to left of cesana pariol during the winter olympics bobsleigh luge and skeleton events took place at this venue the men curling bronze medal match at pinerolo between great britain and the united states was interrupted by streaker wearing rubber chicken as loin cloth at cesana pariol the women singles luge event had thirteen crashes or near crashes during the four runs among those who crashed were american samantha retrosi who was knocked unconscious at the end of the second run while italy anastasia oberstolz antonova crashed out during the first run during the men super alpine skiing event at sestriere borgata seventeen skiers had gone down the course in the morning portion of the event before it was halted to heavy snowfall the event was restarted in the afternoon with all morning results cancelled norway kj ...
#  (16.157061540484325,
#   'Wikipedia',
#   'for the winter olympics in innsbruck austria total of eight sports venues were used luge made its debut at these games but were marred by the death of british slider two weeks prior to the games second ski jumping event debuted and the best two out of three jumps were used in both events for the only time in the history of the winter olympics all eight venues would be used again when the winter games returned to innsbruck twelve years later though the venues would undergo renovations in time for the games venues venue sports capacity ref axamer lizum alpine skiing all but men downhill not listed bergiselschanze ski jumping large hill bob und rodelbahn igls bobsleigh luge not listed speed skating messehalle ice hockey olympiahalle figure skating ice hockey patscherkofel alpine skiing men downhill not listed seefeld biathlon cross country skiing nordic combined ski jumping normal hill not listed before the olympics before the winter games innsbruck hosted several world and european championships they hosted the alpine world ski championships both in and in innsbruck served as host to the fis nordic world ski championships innsbruck hosted its first bobsleigh world championships in in the two man event then hosted again in when the bobsleigh part of the track was used as test event for the games luge was also completed at the same time though kazimierz kay skrzypeski of great britain was killed in practice run on the luge part of the track two weeks before the start of the games igls also served as host of the european luge championships in though the track used was not constructed until since ski jumping season bergiselschanze has been part of the four hills tournament seefeld hosted the biathlon world championships in which also served as test event for the games during the olympics the ski jumping events were the only one in winter olympic history to use the best two out of three jumps for medals this saved finland veikko kankkonen in the normal hill event after he followed disastrous first jump with the longest second and the second longest third jumps after the olympics bergiselschanze continued to play host as one of the hills for the four hills tournament innsbruck would host the winter olympics twelve years later following the withdrawal of denver colorado in the united states for those games in late all eight venues from the games were used for the games with some improvements the bobsleigh and luge tracks were demolished and converted into an artificially refrigerated combination track the first of its kind in the world ski jumps at bergsiel and seefeld both had improving judging stations two new artificial ice rinks were built one for figure skating and the other for ice hockey eischnellaufen had new refrigeration done on its lap circuit references'),
#  (16.098253161597384,
#   'Wikipedia',
#   'lausanne was successful bid by the city of lausanne and the swiss olympic association to host the winter youth olympics the ioc selected the host city for the winter youth olympics at the th ioc session in kuala lumpur malaysia on july which lausanne won history applicant city phase the headquarters of the international olympic committee in lausanne lausanne bid for the winter youth olympics was confirmed on july the city is where the international olympic committee is headquartered lausanne is also home to many sport federations the bid was formally put forward in august lausanne was signed youth olympic game candidature procedure on december previous bids the city of lausanne made several bids in the past lausanne bid to host the summer olympics in but lost to berlin the city again bid for the summer olympics which was awarded to london however those games were cancelled because of the second world war london hosted the summer olympics lausanne bid to host the summer olympics but lost to rome previous bids by other swiss cities st moritz hosted the and winter olympics st moritz unsuccessfully bid to host the and winter olympics and lost to garmisch partenkirchen and squaw valley respectively sion bid to host the and winter olympics but lost to denver salt lake city and turin respectively denver pulled out as host of the games and innsbruck ultimately hosted the games venues lausanne palais de beaulieu figure skating short track curling stade pierre de coubertin opening and closing ceremonies medal ceremonies unil epfl sport centre speed skating centre intercommunal de glace de malley hockey lausanne campus olympic village jura prémanon france ski jumping biathlon nordic combined le brassus cross country skiing alps leysin les mosses les diablerets villars sur ollon notes and references external links official website'),
#  (16.08534300905383,
#   'Wikipedia',
#   'claude quenneville is canadian sports commentator in quebec he served as the french language radio voice of the montreal canadiens of the national hockey league he began his career at the age of at radio station cjmt am in chicoutimi and was later hired by the cbc as an announcer in in he hosted weekly variety show called tempo he became well known by becoming the announcer for radio broadcasts for games played by the montreal canadiens from to he also hosted the popular show la soirée du hockey on src and been long time commentator on olympic events including weightlifting events at the olympics in montreal diving events at the olympics in los angeles gymnastics events at the olympics in seoul athletics in atlanta at the olympics and ice hockey in nagano at the winter olympics quenneville has also covered the commonwealth games of edmonton of edinburgh and victoria his work as sports commentator has earned him two gémeaux awards the first in for the best sports commentator and the second in with gilles tremblay for la soirée du hockey references'),
#  (16.063460868705345,
#   'Wikipedia',
#   'five cities made the shortlist with their bids to host the summer olympics formally known as games of the xxviii olympiad which were awarded to athens on september the other shortlisted cities were rome cape town stockholm and buenos aires final selection in the first round of voting buenos aires and cape town tied with the lowest number of votes round two was therefore tie breaker round between the two cities with buenos aires being eliminated stockholm was the next city to be eliminated followed by cape town the final round saw athens receive enough votes to defeat rome and win the right to host the summer olympics official voting results athens was the leader in all rounds of voting except in round which was tie breaker due to first round tie between cape town and buenos aires cape town won that round over buenos aires before losing out in the th round host city election ballot results city country noc round run off round round round athens rome cape town stockholm buenos aires bidding cities candidate cities the colosseum one of rome most famous landmarks the acropolis of athens logolink city country national olympic committee result px athens hellenic olympic committee hoc winner the city of athens greece submitted bid for the games and won the election in the final round of voting defeating rome athens previously hosted the first modern olympic games in and bid for the summer olympics which were awarded to london but cancelled due to world war ii and the summer olympics athens campaign logo is represented by watercolor version of an olympic cauldron with the flame shaped as capital rome italian national olympic committee coni first runner up the city of rome italy submitted bid for the games and lost the election in the final round of voting being defeated by athens rome was previously awarded the summer olympics but the eruption of mount vesuvius forced the italians to return the games to the ioc and passed the honors to london it would have been the second time rome hosted the games after the summer olympics rome also bid for the the cancelled games and was recently candidate city for the summer olympics but withdrew its bid two years after rome lost their bid turin was awarded the winter olympics rome campaign logo depicts an stylized version of coloseum backgrounded by the sun cape town south african sports confederation and olympic committee sascoc second runner up the city of cape town south africa submitted bid for the games and received the third most votes tying with buenos aires in the first round of voting and winning the run off cape town never hosted the summer olympics or bid before it was africa first bid since alexandria egypt failed its bids to host the cancelled summer olympics and the summer olympics both of which were awarded to berlin had cape town won the rights to host the olympic games it would have been the first olympic games in the continent of africa south africa was awarded the fifa world cup on may and cape town was one of the host cities cape town campaign logo consists of an stylized map of africa colored with the colors of the olympic rings which is formed around the location of cape town in the south of the continent stockholm swedish olympic committee sok third runner up the city of stockholm sweden submitted bid for the games and was eliminated in the third round of voting stockholm previously hosted the summer olympics as well as co hosted the summer olympics with melbourne stockholm campaign logo depicts the statue man and pegasus located at millesgården just outside stockholm its hopes were ruined when sports arenas in stockholm and göteborg were damaged by explosive bombs and arson attacks by mats hinze px buenos aires argentine olympic committee coa fourth runner up the city of buenos aires argentina submitted bid for the games and was eliminated in run off against cape town since both cities tied in the first round of voting buenos aires never hosted the summer olympics but bi ...
#  (16.02462937593157,
#   'Wikipedia',
#   'dundumwezi is modified word from its original dundumwenze which means male mountain is constituency in chief siachitema in the south west of kalomo district of southern province zambia it is an underdeveloped remote constituency that lacks infrastructure and basic necessities and is often ignored by the government it lacks roads hospitals schools and housing demographics dundumwezi is inhabited by the tonga people of zambia august election in dundumwezi constituents favored an independent candidate over the popular united party for national development upnd candidate in the august general election voters showed overwhelming support for the leading opposition party president hakainde hichilema while only voted for the ruling party president edgar lungu who had never visited the area until july the elections were marred by violence instigated by the ruling patriotic front pf party against supporters of the opposition parties the counting process took three days the result was called into question by many opposition parties they accused the ruling party of delaying the release of the result granting election server access to foreign it specialists with connections to the ruling party disposing of opposition party ballot papers that were discovered in bin having pre marked ballot papers and allowing unverified ballot papers to be counted the area had been visited by sitting president once in and ignored thereafter following the visit of his excellence mr edgar lungu this year he has recognized and respected the cry of the people to develop dundumwezi the president is committed and has since included it in the national development plan despite having received few votes from the area tourism has also been extended in dundumwezi as development takes off references external links'),
#  (16.009292789330587,
#   'Wikipedia',
#   'communist party congress could refer to ruling or former ruling communist parties congress of the socialist unity party of germany national congress of the communist party of vietnam national congress of the communist party of china congress of the romanian communist party congress of the communist party of the soviet union congresses of the communist party of lithuania non ruling communist party congresses congresses of the communist party of brazil'),
#  (15.943671862094131,
#   'Wikipedia',
#   'there were six bids initially submitted for the summer olympics tokyo was ultimately elected as the host city at the th ioc session in buenos aires argentina on september bidding process the olympic bidding process begins with the submission of city application to the international olympic committee ioc by its national olympic committee noc and ends with the election of the host city by the members of the ioc during an ordinary session the process is governed by the olympic charter as stated in chapter rule since the process has consisted of two phases during the first phase which begins immediately after the bid submission deadline the applicant cities are required to answer questionnaire covering themes of importance to successful games organization this information allows the ioc to analyze the cities hosting capacities and the strengths and weaknesses of their plans following detailed study of the submitted questionnaires and ensuing reports the ioc executive board selects the cities that are qualified to proceed to the next phase the second phase is the true candidature stage the accepted applicant cities from now on referred to as candidate cities are required to submit second questionnaire in the form of an extended more detailed candidature file these files are carefully studied by the ioc evaluation commission group composed of ioc members representatives of international sport federations nocs athletes the international paralympic committee and international experts in various fields it is chaired by sir craig reedie the members of the evaluation commission then make four day inspection visits to each of the candidate cities where they check the proposed venues and are briefed about details of the themes covered in the candidature file the evaluation commission communicates the results of its inspections in report sent to the ioc members up to one month before the electing ioc session the ioc session in which host city is elected takes place in country that did not submit an application to stage the olympics the election is made by the assembled active ioc members excluding honorary and honor members each possessing one vote members from countries that have city taking part in the election cannot vote while the city is in the running the voting is conducted in succession of rounds until one bid achieves an absolute majority of votes if this does not happen in the first round the bid with the fewest votes is eliminated and another voting round begins in the case of tie for the lowest number of votes special runoff vote is carried out with the winner proceeding to the next round after each round the eliminated bid is announced following the announcement of the host city the successful bid delegation signs the host city contract with the ioc which delegates the of the games organisation to the city and respective noc bidding timeline the timeline of the host city selection process was approved by the international olympic committee ioc executive board as follows may ioc sent letters inviting the national olympic committees nocs to submit bids july and august ioc asked for nocs to submit letters regarding compliance with the world anti doping agency code by july the ioc also requested submissions of proposed dates if countries want to stage the games outside the normal period set by the ioc july to august the ioc responded to nocs on these points by the end of august september deadline to submit the names of cities interested in hosting the summer games september ioc confirmed that they had received six bids november ioc held an information seminar for applicants december ioc announced the drawing lots order of applicant cities february application files and guarantee letters submitted to the ioc may ioc executive board in quebec city decided which cities were to be approved as official candidate cities july august olympic games observers programme at the games of the xxx olympiad in london november olympic games debr ...
#  (15.932951385563095,
#   'Wikipedia',
# ...
#  (15.444647559845158,
#   'Wikipedia',
#   'the popular action of equatorial guinea is political party in the equatorial guinea it is led by carmelo mba bacalé it is currently one of many opposition parties in the country banned by the ruling party the democratic party of equatorial guinea the ruling party since despite being an illegal party bacalé gained of the country vote for the ap in the equatoguinean presidential election references'),
#  (15.43243148059007,
#   'Wikipedia',
#   'the winter olympics which would have been officially known as the were to have been celebrated from to february in sapporo japan but the games were eventually cancelled due to the onset of world war ii sapporo subsequently hosted the winter olympics history sapporo was selected to be the host of the fifth edition of the winter olympics scheduled february but japan gave the games back to the ioc in july after the outbreak of the second sino japanese war in the ioc then decided to give the winter olympics to st moritz switzerland which had hosted it in however the swiss organizers believed that ski instructors should be considered professionals the ioc was not of that mind and the games were withdrawn again in the spring of the ioc gave the winter olympics now scheduled for february to garmisch partenkirchen germany where the previous games had been held five months later on september germany invaded poland igniting world war ii and the winter games were cancelled in november likewise the games awarded in to cortina ampezzo italy were cancelled in st moritz held the first post war games in while cortina ampezzo hosted in germany has not hosted the winter olympics since on july munich lost to pyeongchang south korea to host the winter games see also external links planned program for the winter olympics in sapporo and garmisch partenkirchen'),
#  (15.390881429605596,
#   'Wikipedia',
#   'olimpiysky pool moscow as seen in the swimming pool at the olimpiysky sports complex is covered swimming centre in moscow russia the venue built for the summer olympics makes up the olimpiysky sports complex architectural ensemble together with the olimpiysky arena during the olympics it hosted the swimming diving water polo and the swimming part of the modern pentathlon events it also hosted short course world championships the venue consists of swimming pool with capacity for spectators separated by an acoustic partition from the diving pool with capacity for spectators see also olympic pool at the luzhniki olympic complex references external links official website of the olympiisky sports complex'),
#  (15.38801518613207,
#   'Wikipedia',
#   'guadalajara was bid by the city of guadalajara and the comité olímpico mexicano to host the summer youth olympics history on february guadalajara bid was selected over monterrey bid to bid to host the summer youth olympics by an inner voting from the mexico national olympic committee it was reported in august that the bid may be in danger due to the debt created by the pan american games guadalajara failed to become candidate city for the games when the ioc selected the candidate cities on february buenos aires was ultimately elected as the host city of the summer youth olympic games on july previous bids from other mexican cities the rotonda de los jaliscienses ilustres at night guadalajara was elected previously to bid to host the summer youth olympics but withdrew their bid following this report nanjing was ultimately awarded the games mexico city hosted the summer olympic games in mexico city made two bids prior to their bid they bid for the and summer olympics but lost to melbourne and rome respectively guadalajara had previously hosted the pan american games and bid for the world aquatics championships but withdrew the championships were awarded to budapest see also monterrey bid for the summer youth olympics mexico at the olympics bids for the summer youth olympics references'),
#  (15.384197671936011,
#   'Wikipedia',
#   'the popular union of equatorial guinea is political party in the equatorial guinea it is led by daniel martinez ayecaba the party was originally banned by the ruling democratic party of equatorial guinea the ruling party since but was legalized in may the up candidate archivaldo montelo biribé gained of the country vote in the equatoguinean presidential election references'),
#  (15.375723900710383,
#   'Wikipedia',
#   'birkebeineren ski stadium is cross country skiing and biathlon venue located in lillehammer norway situated from the town center and at above mean sea level it has two stadium areas one for cross country and one for biathlon the former has capacity for spectators and the latter for the venue was built for the winter olympics costing million norwegian krone nok it was subsequently used by the winter paralympics for paralympic nordic skiing and paralympic biathlon after the games ownership was transferred to the municipal lillehammer olympiapark the venue has since been used for one biathlon world cup three fis cross country world cup and nine fis nordic combined world cup tournaments the latter with the ski jumping competition taking place at the nearby lysgårdsbakkene ski jumping arena birkebeineren hosted the winter youth olympics construction the location of the venue was decided in january following lillehammer successful bid to host the winter olympics construction was managed by the lillehammer olympic organizing committee looc architects were arkitekter and the main consultant was tonning lieng construction started in early before planning was completed and lasted until the construction work was subcontracted to several companies landscaping was completed in the facilities used concrete and wood as the main materials the stadium included of temporary buildings building converted to riding center after the olympics and tent the land around the venue is swamp and most of the surface soil had to be removed and replaced with harder earth the soil was used as fertilizer or fill in other parts of the arena creek had to be bypassed with long pipe the arena is also so flat that drainage system had to be installed after the olympics four temporary overpasses were removed construction of the tracks was done to minimize the impact on the forest the venue cost nok million and was inaugurated on november with an international biathlon competition in december the looc stated that they wanted to upgrade the stadium spectator capacity but that the transport systems would not allow more people in the stadium had world cup tournaments in biathlon and cross country skiing as trial before the olympics during several events the computer system controlling the scoreboard and television scores collapsed president johan baumann of the norwegian ski federation criticized the venue and demanded that new stadium be built he stated that the stadium had been built to optimize television pictures and that it had insufficient facilities for the spectators in particular he criticized the fact that the spectators were too far away from the skiers and the lack of television screen and more scoreboards in may the looc announced that the stadium would be expanded for another people before the olympics on september the ownership of the venue was transferred from the looc to lillehammer municipality via the subsidiary lillehammer olympiavekst which later changed its name to lillehammer olympiapark in october the forest along the tracks were partially cleared to allow spectators without tickets to watch the events facilities the arena covers an area of and is from the town center for the olympics of cross country tracks and of biathlon tracks were built there are two stadiums one for cross country skiing and one for biathlon the former has spectator capacity for while the latter has capacity for in addition up to people watched the events the trackside during the olympics permanent buildings include finishing house for biathlon finishing house for cross country plant room the cross country stadium is long while the biathlon stadium is long the biathlon stadium has shooting stations the facility has kva transformer with an additional transformer used during the olympics critical systems such as computers and time keeping equipment have an uninterruptible power supply as recreational venue birkebeineren connects to of skiing tracks including lighted track wh ...
#  (15.35143907463622,
#   'Wikipedia',
#   'right start at the cresta run in st moritz host of the skeleton events for both the and winter olympics turn at the whistler sliding centre in for the winter olympics in vancouver the venue hosted the skeleton events for the winter olympics there have been six venues that have been or will be used for skeleton when the winter olympics were in st moritz they took place at the cresta run for both and since being re introduced at the winter olympics skeleton has shared the same venue with the other sliding sports of bobsleigh and luge games venue other sports hosted at venue for those games capacity ref st moritz cresta run none not listed st moritz cresta run none not listed salt lake city utah olympic park includes bobsleigh luge and skeleton track bobsleigh luge nordic combined ski jumping ski jumping ski jumping bobsleigh luge skeleton turin cesana pariol bobsleigh luge vancouver the whistler sliding centre bobsleigh luge sochi sliding center sanki bobsleigh luge pyeongchang alpensia sliding centre bobsleigh luge references'),
#  (15.33618124931852,
#   'Wikipedia',
#   'aerial view of the current bobsleigh luge and skeleton track at the winter games this was where the luge track was located the bobsleigh track used for the and winter olympics no longer in use is seen at the lower part of the picture for the winter olympics in lake placid new york united states total of seven sports venues were used all five of the venues used for the winter olympics were also used at the winter games with adjustments these adjustments included electronic scoreboards increased refrigeration and the addition of separate luge track this was the last winter olympics where there were separate bobsleigh and luge tracks the closest finish in olympic history in cross country skiing led skiing officials to time future events in hundredths of second rather than tenths of second this would also apply to biathlon events eric heiden of the united states won five gold medals at the speed skating oval while the miracle on ice took place between americans and soviets at the olympic center in the late the luge track was demolished and new combination track was constructed in time for the only winter goodwill games held the sliding venue was named to the american national register of historical places in february venues map of the venues in lake placid venue sports capacity ref intervales ski hill nordic combined ski jumping ski jumping lake placid equestrian stadium opening ceremonies lake placid olympic sports complex cross country biathlon center biathlon cross country skiing nordic combined cross country skiing not listed mt van hoevenberg bob and luge run bobsleigh luge separate tracks bobsleigh olympic center arena figure skating ice hockey olympic arena james sheffield speed skating oval speed skating whiteface mountain alpine skiing not listed before the olympics lake placid hosted the winter olympics in with all five venues used for those games being used for the winter olympics the city made four unsuccessful bids for the winter olympics in and before being awarded the winter olympics by the international olympic committee ioc in between the winter games and the winter games lake placid played host to winter sports championships the first time many of them were held outside of europe after the games the speedskating oval hosted the world allround speed skating championships for men the bob run hosted the fibt world championships in and in the fis nordic world ski championships took place at the ski jump used for the games for the ski jumping and the ski jumping part of the nordic combined event biathlon held their first world championships outside of europe at lake placid in when lake placid was awarded the winter games in venue adjustments were needed for the alpine skiing events snow making equipment was used this was used to make of man made snow to cover all of the trails used for the events six new ski lifts and electronic timing scoring systems were also constructed for the nordic skiing events cross country skiing nordic combined ski jumping total of event officials were sent as observers to the world championships in lahti finland to understand the venue needs for the games for the km race total of was purchased and trail system was created that involved tree clearing man made snow was also applied for the cross country skiing trail races over km in length were modified to meet the snow requirements as defined by the international ski federation an electronic scoreboard was installed for the cross country skiing events this information was passed onto organizers for the winter olympics in sarajevo two new ski jumps were constructed the jump was constructed between may and december construction for the jump also started in may but was not done until the february test event to construction delays caused by the bankruptcy of the steel contractor biathlon used trails similar to cross country skiing though separate finish area was used protective shooting area of was built for the competition of for shooting st ...
#  (15.295942665184704,
#   'Wikipedia',
#   'is mountain located in yamanouchi nagano japan for the winter olympics it hosted the alpine skiing slalom and snowboarding giant slalom events during the games the mountain suffered mild earthquake that registered on the richter magnitude scale but the skiing events continued references winter olympics official report volume pp poor skiing conditions nothing new to whistler february toronto observer article accessed september shinmai co jp winter olympics venue profile'),
#  (15.244994561315828,
#   'Wikipedia',
#   'the camp olímpic de tir amb arc was temporary venue located in barcelona it hosted the archery competitions for the summer olympics it was located in site at the ronda de dalt next to the pavelló de la vall hebron in the barcelona district of horta guinardó after the olympics it was remodelled into ciutat esportiva municipal vall hebron teixonera which consists of two football soccer fields rugby field and an annexe service area references summer olympics official report volume pp'),
#  (15.21769728323561,
#   'Wikipedia',
#   'the hon clyde mascoll is politician from barbados he is former leader of the democratic labour party dlp in mascoll unsuccessfully led the party in an election against the ruling barbados labour party blp however after internal disagreement within the dlp mascoll crossed the floor to become member of the ruling blp in becoming minister of state in the ministry of finance he was defeated in his st michael north west constituency by the dlp christopher sinckler in the january general election receiving of the vote references')]

# %%
# 4) Attribute Retriever
enc = SentenceTransformer("paraphrase-mpnet-base-v2", device=device)

def attribute_retrieve(
    question: str,
    docs: list[tuple[float,str,str]],
    top_k: int = 10
) -> list[tuple[str,float]]:
    """
    Mask title words, split docs into sentences, and return
    the top_k (sentence, score) by dense similarity.
    """
    mask = {w.lower() for _, title, _ in docs for w in title.split() if w.isalpha()}
    q_mask = " ".join(w for w in question.split() if w.lower() not in mask)

    sents, masked = [], []
    for _, _, para in docs:
        for s in sent_tokenize(para):
            sents.append(s)
            masked.append(" ".join(w for w in s.split() if w.lower() not in mask))

    q_vec = enc.encode(q_mask, convert_to_tensor=True)
    s_vecs = enc.encode(masked, convert_to_tensor=True)
    cos   = util.cos_sim(q_vec, s_vecs)[0]
    topi  = torch.topk(cos, k=min(top_k, len(sents))).indices

    return [(sents[i], float(cos[i])) for i in topi]
# Out:
# modules.json:   0%|          | 0.00/229 [00:00<?, ?B/s]
# config_sentence_transformers.json:   0%|          | 0.00/122 [00:00<?, ?B/s]
# README.md:   0%|          | 0.00/3.52k [00:00<?, ?B/s]
# sentence_bert_config.json:   0%|          | 0.00/53.0 [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/594 [00:00<?, ?B/s]
# model.safetensors:   0%|          | 0.00/438M [00:00<?, ?B/s]
# tokenizer_config.json:   0%|          | 0.00/1.19k [00:00<?, ?B/s]
# vocab.txt:   0%|          | 0.00/232k [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/466k [00:00<?, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/239 [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/190 [00:00<?, ?B/s]

# %%
#question = "What is the ruling party of the country that hosted the 2016 Olympics?"

# %%
# ─── Cell X+2: Attribute Retrieval ──────────────────────────────────────────
top_sents = attribute_retrieve(question, docs, top_k=5)

print("Top 5 sentences:")
for sent, sc in top_sents:
    print(f"{sc:.2f} → {sent}")
# Out:
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/2 [00:00<?, ?it/s]
# Top 5 sentences:
# 0.53 → there were six bids initially submitted for the summer olympics tokyo was ultimately elected as the host city at the th ioc session in buenos aires argentina on september bidding process the olympic bidding process begins with the submission of city application to the international olympic committee ioc by its national olympic committee noc and ends with the election of the host city by the members of the ioc during an ordinary session the process is governed by the olympic charter as stated in chapter rule since the process has consisted of two phases during the first phase which begins immediately after the bid submission deadline the applicant cities are required to answer questionnaire covering themes of importance to successful games organization this information allows the ioc to analyze the cities hosting capacities and the strengths and weaknesses of their plans following detailed study of the submitted questionnaires and ensuing reports the ioc executive board selects the cities that are qualified to proceed to the next phase the second phase is the true candidature stage the accepted applicant cities from now on referred to as candidate cities are required to submit second questionnaire in the form of an extended more detailed candidature file these files are carefully studied by the ioc evaluation commission group composed of ioc members representatives of international sport federations nocs athletes the international paralympic committee and international experts in various fields it is chaired by sir craig reedie the members of the evaluation commission then make four day inspection visits to each of the candidate cities where they check the proposed venues and are briefed about details of the themes covered in the candidature file the evaluation commission communicates the results of its inspections in report sent to the ioc members up to one month before the electing ioc session the ioc session in which host city is elected takes place in country that did not submit an application to stage the olympics the election is made by the assembled active ioc members excluding honorary and honor members each possessing one vote members from countries that have city taking part in the election cannot vote while the city is in the running the voting is conducted in succession of rounds until one bid achieves an absolute majority of votes if this does not happen in the first round the bid with the fewest votes is eliminated and another voting round begins in the case of tie for the lowest number of votes special runoff vote is carried out with the winner proceeding to the next round after each round the eliminated bid is announced following the announcement of the host city the successful bid delegation signs the host city contract with the ioc which delegates the of the games organisation to the city and respective noc bidding timeline the timeline of the host city selection process was approved by the international olympic committee ioc executive board as follows may ioc sent letters inviting the national olympic committees nocs to submit bids july and august ioc asked for nocs to submit letters regarding compliance with the world anti doping agency code by july the ioc also requested submissions of proposed dates if countries want to stage the games outside the normal period set by the ioc july to august the ioc responded to nocs on these points by the end of august september deadline to submit the names of cities interested in hosting the summer games september ioc confirmed that they had received six bids november ioc held an information seminar for applicants december ioc announced the drawing lots order of applicant cities february application files and guarantee letters submitted to the ioc may ioc executive board in quebec city decided which cities were to be approved as official candidate cities july august olympic games observers programme at the games of the xxx olympiad in london november olympic games  ...
# 0.49 → five cities made the shortlist with their bids to host the summer olympics formally known as games of the xxviii olympiad which were awarded to athens on september the other shortlisted cities were rome cape town stockholm and buenos aires final selection in the first round of voting buenos aires and cape town tied with the lowest number of votes round two was therefore tie breaker round between the two cities with buenos aires being eliminated stockholm was the next city to be eliminated followed by cape town the final round saw athens receive enough votes to defeat rome and win the right to host the summer olympics official voting results athens was the leader in all rounds of voting except in round which was tie breaker due to first round tie between cape town and buenos aires cape town won that round over buenos aires before losing out in the th round host city election ballot results city country noc round run off round round round athens rome cape town stockholm buenos aires bidding cities candidate cities the colosseum one of rome most famous landmarks the acropolis of athens logolink city country national olympic committee result px athens hellenic olympic committee hoc winner the city of athens greece submitted bid for the games and won the election in the final round of voting defeating rome athens previously hosted the first modern olympic games in and bid for the summer olympics which were awarded to london but cancelled due to world war ii and the summer olympics athens campaign logo is represented by watercolor version of an olympic cauldron with the flame shaped as capital rome italian national olympic committee coni first runner up the city of rome italy submitted bid for the games and lost the election in the final round of voting being defeated by athens rome was previously awarded the summer olympics but the eruption of mount vesuvius forced the italians to return the games to the ioc and passed the honors to london it would have been the second time rome hosted the games after the summer olympics rome also bid for the the cancelled games and was recently candidate city for the summer olympics but withdrew its bid two years after rome lost their bid turin was awarded the winter olympics rome campaign logo depicts an stylized version of coloseum backgrounded by the sun cape town south african sports confederation and olympic committee sascoc second runner up the city of cape town south africa submitted bid for the games and received the third most votes tying with buenos aires in the first round of voting and winning the run off cape town never hosted the summer olympics or bid before it was africa first bid since alexandria egypt failed its bids to host the cancelled summer olympics and the summer olympics both of which were awarded to berlin had cape town won the rights to host the olympic games it would have been the first olympic games in the continent of africa south africa was awarded the fifa world cup on may and cape town was one of the host cities cape town campaign logo consists of an stylized map of africa colored with the colors of the olympic rings which is formed around the location of cape town in the south of the continent stockholm swedish olympic committee sok third runner up the city of stockholm sweden submitted bid for the games and was eliminated in the third round of voting stockholm previously hosted the summer olympics as well as co hosted the summer olympics with melbourne stockholm campaign logo depicts the statue man and pegasus located at millesgården just outside stockholm its hopes were ruined when sports arenas in stockholm and göteborg were damaged by explosive bombs and arson attacks by mats hinze px buenos aires argentine olympic committee coa fourth runner up the city of buenos aires argentina submitted bid for the games and was eliminated in run off against cape town since both cities tied in the first round of voting buenos aires never hosted the summer olympics bu ...
# 0.49 → london hosted the olympic games in and the summer olympics made london the first city to have hosted the modern games of three olympiads london is the only city in the united kingdom to have ever hosted the olympics the united states is the only country to have hosted summer olympics on more occasions than the uk also london is the only city to have bid more than once and still hold record british participation in olympic events both as competitor and as host is the responsibility of the british olympic association summer olympics london olympics the summer olympics the games of the iv olympiad were the fifth modern olympic games and the third to be hosted outside of athens greece the international olympic committee considers them the fourth olympic games discounting the intercalated summer olympics the olympic games were scheduled to take place in rome but the eruption of mount vesuvius on april required the italian government to redirect funds away from the olympics the events took place between april and october with nations participating in events the british team easily topped the unofficial medal count finishing with three times as many medals as the second place united states summer olympics the summer olympics the games of the xiii olympiad were scheduled to be held in london awarded in they were however cancelled due to world war ii these games would have celebrated the th anniversary of the modern olympiad summer olympics the summer olympics the games of the xiv olympiad were the first to be held after world war ii with the summer olympics having been cancelled due to the war showing collective unity after the war nations competed in different events between july and august germany and japan were not invited to the games due to security reasons unlike the previous time the uk hosted the olympics the british athletes did not have high medal count finishing th in the unofficial medal count with only medals summer olympics the summer olympics the games of the xxx olympiad took place between july and august the london olympic bid was announced as the winner of the bidding process on july following unsuccessful bid attempts for previous olympics by manchester and birmingham team gb finished rd with gold medals and total medals representing their best medal haul since london first hosted the olympics in summer paralympics the summer paralympics were the fourteenth paralympics and took place between august and september at the summer olympics venues in london external links london olympic games official website london olympic games information portal commentary on olympic park
# 0.48 → map of host cities and countries of the modern summer orange and winter blue olympics tap or hover over city to show its name this is list of host cities of the olympic games both summer and winter since the modern olympics began in since then summer and winter games have usually celebrated four year period known as an olympiad summer and winter games normally held in staggered even years there have been summer olympic games held in cities and winter olympic games held in cities in addition three summer and two winter editions of the games were scheduled to take place but later cancelled due to war berlin summer in tokyo helsinki summer and sapporo garmisch partenkirchen winter in and london summer and cortina winter in the intercalated olympics were officially sanctioned and held in athens however in the international olympic committee ioc decided to unrecognize the games the summer olympics in tokyo were postponed for the first time in olympics history to summer due to the covid pandemic with the winter olympics being held roughly six months later in beijing the youth olympic games are held every four years in staggered summer and winter events consistent with the current olympic games format though in reverse order with winter games held in leap years instead of summer games the first summer version was held in singapore from to august while the first winter version was held in innsbruck austria from to january five cities have been chosen by the ioc to host upcoming olympic games tokyo for the summer olympics beijing for the winter olympics paris for the summer olympics milan cortina for the winter olympics and los angeles for the summer olympics additional two cities have been chosen by the ioc to host upcoming youth olympic games dakar for the summer youth olympics and gangwon province for the winter youth olympics in beijing will become the first ever city that has held both the summer and the winter olympic games eleven cities will have hosted the olympic games more than once athens and summer olympics paris and summer olympics london and summer olympics st moritz and winter olympics lake placid and winter olympics los angeles and summer olympics cortina ampezzo and winter olympics innsbruck and winter olympics and winter youth olympics tokyo and summer olympics lillehammer winter olympics and winter youth olympics gangwon province pyeongchang winter olympics and winter youth olympics and beijing summer olympics and winter olympics stockholm hosted the summer olympics and the equestrian portion of the summer olympics london became the first city to have hosted three games with the summer olympics paris will become the second city to do this with the summer olympics followed by los angeles as the third in the united states has hosted total of eight olympic games more than any other country followed by france with five editions switzerland the united kingdom austria canada italy japan and germany have each hosted three games the games have primarily been hosted in the continents of europe editions and americas editions seven games have been hosted in asia and two have been hosted in oceania in singapore became southeast asia first olympic host city for the inaugural summer youth olympics while rio de janeiro became south america first olympic host city with the summer olympics followed by buenos aires with the summer youth olympics the summer youth olympics in dakar will become the first ever games to be held on the african continent other major geographic regions which have never hosted the olympics include the middle east central asia the indian subcontinent central america and the caribbean host cities are selected by the ioc membership usually seven years in advance the selection process lasts approximately two years in the first stage any city in the world may submit an application to become host city after months the executive board of the ioc decides which applicant cities will become official candidates as ...
# 0.44 → paris has hosted several olympiads and and will host in paris will be the second city in the modern games to have hosted three olympiads when paris hosts the summer olympics the other being london the french national olympic and sports committee oversees france interests in the olympics summer olympics paris summer olympics the summer olympics the games of the ii olympiad were the third modern olympics and the inaugural hosted outside of athens greece the international olympic committee considers them the second olympics discounting the intercalated summer olympics the summer olympics were held simultaneously with the world fair the events took place between may and october with nations participating in events the french team topped the unofficial medal count finishing with three times as many medals as the second place united states while fielding ten times as many athletes summer olympics the summer olympics the games of the viii olympiad were the second to be held after world war showing collective unity after the war nations competed in different events between may and july germany was not invited to the games due to security reasons unlike the previous time france hosted the olympics the french athletes did not have high medal count finishing rd in the unofficial medal count with only medals summer olympics the summer olympics the games of the xxxiii olympiad will take place from july to august the paris olympic bid was announced as the winner of the bidding process on september following unsuccessful bid attempts for previous olympiads summer paralympics the summer paralympics will be the seventeenth paralympics and will take place between august and september at the summer olympics venues in paris external links paris olympic games official website

# %% [markdown]
# cached retrieved results and sentences

# %%
# ─── Cell X+3: Cache the Retrieved Sentences ────────────────────────────────
import os, json

CACHE_DIR = "cache"
os.makedirs(CACHE_DIR, exist_ok=True)

sents_path = os.path.join(CACHE_DIR, "sents.json")

# Quick check: ensure we have some sentences
assert len(top_sents) > 0, "No sentences retrieved—check your attribute retriever!"
print("Sample sentence:", top_sents[0])

# Save out
with open(sents_path, "w", encoding="utf-8") as f:
    json.dump(
        [{"sent": s, "score": sc} for s, sc in top_sents],
        f, ensure_ascii=False, indent=2
    )
print("✅ Saved", len(top_sents), "sentences to", sents_path)

# Verify
size = os.path.getsize(sents_path)
print("File size:", size, "bytes")
loaded = json.load(open(sents_path, "r", encoding="utf-8"))
print("Loaded entries:", len(loaded))
# Out:
# Sample sentence: ('there were six bids initially submitted for the summer olympics tokyo was ultimately elected as the host city at the th ioc session in buenos aires argentina on september bidding process the olympic bidding process begins with the submission of city application to the international olympic committee ioc by its national olympic committee noc and ends with the election of the host city by the members of the ioc during an ordinary session the process is governed by the olympic charter as stated in chapter rule since the process has consisted of two phases during the first phase which begins immediately after the bid submission deadline the applicant cities are required to answer questionnaire covering themes of importance to successful games organization this information allows the ioc to analyze the cities hosting capacities and the strengths and weaknesses of their plans following detailed study of the submitted questionnaires and ensuing reports the ioc executive board selects the cities that are qualified to proceed to the next phase the second phase is the true candidature stage the accepted applicant cities from now on referred to as candidate cities are required to submit second questionnaire in the form of an extended more detailed candidature file these files are carefully studied by the ioc evaluation commission group composed of ioc members representatives of international sport federations nocs athletes the international paralympic committee and international experts in various fields it is chaired by sir craig reedie the members of the evaluation commission then make four day inspection visits to each of the candidate cities where they check the proposed venues and are briefed about details of the themes covered in the candidature file the evaluation commission communicates the results of its inspections in report sent to the ioc members up to one month before the electing ioc session the ioc session in which host city is elected takes place in country that did not submit an application to stage the olympics the election is made by the assembled active ioc members excluding honorary and honor members each possessing one vote members from countries that have city taking part in the election cannot vote while the city is in the running the voting is conducted in succession of rounds until one bid achieves an absolute majority of votes if this does not happen in the first round the bid with the fewest votes is eliminated and another voting round begins in the case of tie for the lowest number of votes special runoff vote is carried out with the winner proceeding to the next round after each round the eliminated bid is announced following the announcement of the host city the successful bid delegation signs the host city contract with the ioc which delegates the of the games organisation to the city and respective noc bidding timeline the timeline of the host city selection process was approved by the international olympic committee ioc executive board as follows may ioc sent letters inviting the national olympic committees nocs to submit bids july and august ioc asked for nocs to submit letters regarding compliance with the world anti doping agency code by july the ioc also requested submissions of proposed dates if countries want to stage the games outside the normal period set by the ioc july to august the ioc responded to nocs on these points by the end of august september deadline to submit the names of cities interested in hosting the summer games september ioc confirmed that they had received six bids november ioc held an information seminar for applicants december ioc announced the drawing lots order of applicant cities february application files and guarantee letters submitted to the ioc may ioc executive board in quebec city decided which cities were to be approved as official candidate cities july august olympic games observers programme at the games of the xxx olympiad in london november ol ...
# ✅ Saved 5 sentences to cache/sents.json
# File size: 29214 bytes
# Loaded entries: 5

# %%
# Load top_sents
if os.path.exists(sents_path):
    with open(sents_path, "r", encoding="utf-8") as f:
        top_sents = [(d["sent"], d["score"]) for d in json.load(f)]
    print(f"✅ Loaded {len(top_sents)} cached sentences")
else:
    raise FileNotFoundError(f"{sents_path} not found; run the Attribute Retriever first.")
# Out:
# ✅ Loaded 5 cached sentences

# %%
import time

count = 0
while True:
    print(count)
    count += 1
    
    print("Waiting for 2 minutes...")
    time.sleep(120)
    print("Resuming execution now.")

# %% [markdown]
# Disintigrated reasoning

# %%
# ─── Cell X: Install & import reasoning deps ────────────────────────────────
# !pip install --no-deps --quiet transformers

import torch.nn as nn
from transformers import RobertaTokenizer, RobertaModel


# 1) Load tokenizer & shared RoBERTa encoder
TOKENIZER = RobertaTokenizer.from_pretrained("roberta-base")
ENCODER   = RobertaModel.from_pretrained("roberta-base")
HIDDEN    = ENCODER.config.hidden_size
NUM_STRAT = 5   # e.g. comparison, logical, entail, binary, numerical
# Out:
# tokenizer_config.json:   0%|          | 0.00/25.0 [00:00<?, ?B/s]
# vocab.json:   0%|          | 0.00/899k [00:00<?, ?B/s]
# merges.txt:   0%|          | 0.00/456k [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/1.36M [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/481 [00:00<?, ?B/s]
# model.safetensors:   0%|          | 0.00/499M [00:00<?, ?B/s]
# Some weights of RobertaModel were not initialized from the model checkpoint at roberta-base and are newly initialized: ['pooler.dense.bias', 'pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.

# %%
device = "cuda" if torch.cuda.is_available() else "cpu"

# %%
# ─── Cell Y: Disentangled Reasoner Definition ───────────────────────────────
class DisentangledReasoner(nn.Module):
    def __init__(self):
        super().__init__()
        self.encoder    = ENCODER
        # Strategy head: softmax over NUM_STRAT
        self.strat_head = nn.Sequential(
            nn.Linear(HIDDEN, HIDDEN//2),
            nn.ReLU(),
            nn.Linear(HIDDEN//2, NUM_STRAT)
        )
        # Answer head: sigmoid yes/no
        self.ans_head   = nn.Sequential(
            nn.Linear(HIDDEN*2, HIDDEN),
            nn.ReLU(),
            nn.Linear(HIDDEN, 1)
        )

    def forward(self, strat_inputs, ans_inputs):
        # strat_inputs: masked q + masked sents
        # ans_inputs: original q + original sents
        # Encode for strategy
        out_strat = self.encoder(**strat_inputs).last_hidden_state[:,0]  # [CLS]
        strat_logits = self.strat_head(out_strat)                       # (B,NUM_STRAT)
        # Encode for answer
        out_ans = self.encoder(**ans_inputs).last_hidden_state[:,0]      # [CLS]
        # Combine
        combined = torch.cat([out_strat, out_ans], dim=-1)              # (B,2*H)
        ans_logit = self.ans_head(combined).squeeze(-1)                 # (B,)
        return strat_logits, ans_logit

# Instantiate
model = DisentangledReasoner().to(device)

# %%
# ─── Cell Z: Prepare inputs & run a single‐example inference ───────────────
# Assume you still have:
#   q         = original question string
#   docs      = output of local_topic_retrieve_mv(...)
#   top_sents = output of attribute_retrieve(q, docs, top_k=5)

q= question

# (A) Build mask set from titles
mask = {w.lower() for _, title, _ in docs for w in title.split() if w.isalpha()}

# (B) Masked inputs for strategy predictor
q_masked = " ".join(w for w in q.split() if w.lower() not in mask)
sents_masked = [
    " ".join(w for w in s.split() if w.lower() not in mask)
    for s,_ in top_sents
]
strat_text = q_masked + " " + " ".join(sents_masked)
strat_inputs = TOKENIZER(
    strat_text,
    padding=True, truncation=True, max_length=512, return_tensors="pt"
).to(device)

# (C) Original inputs for answer predictor
orig_sents = [s for s,_ in top_sents]
ans_text = q + " " + " ".join(orig_sents)
ans_inputs = TOKENIZER(
    ans_text,
    padding=True, truncation=True, max_length=512, return_tensors="pt"
).to(device)

# (D) Inference
model.eval()
with torch.no_grad():
    strat_logits, ans_logit = model(strat_inputs, ans_inputs)
    strat_pred = torch.argmax(strat_logits, dim=-1).item()
    ans_prob  = torch.sigmoid(ans_logit).item()

# (E) Print
STRAT_LABELS = ["comparison","logical","entail","binary","numerical"]
print("Predicted strategy:", STRAT_LABELS[strat_pred])
print("Answer probability:", ans_prob)
print("Predicted answer:", "Yes" if ans_prob>0.5 else "No")
# Out:
# Predicted strategy: entail
# Answer probability: 0.5046440362930298
# Predicted answer: Yes

# %%
import time

count = 0
while True:
    print(count)
    count += 1
    
    print("Waiting for 2 minutes...")
    time.sleep(120)
    print("Resuming execution now.")
# Out:
# 0
# Waiting for 2 minutes...
# Resuming execution now.
# 1
# Waiting for 2 minutes...
# Resuming execution now.
# 2
# Waiting for 2 minutes...
# Resuming execution now.
# 3
# Waiting for 2 minutes...
# Resuming execution now.
# 4
# Waiting for 2 minutes...
# Resuming execution now.
# 5
# Waiting for 2 minutes...
# Resuming execution now.
# 6
# Waiting for 2 minutes...
# Resuming execution now.
# 7
# Waiting for 2 minutes...
# Resuming execution now.
# 8
# Waiting for 2 minutes...
# Resuming execution now.
# 9
# Waiting for 2 minutes...
# Resuming execution now.
# 10
# Waiting for 2 minutes...
# Resuming execution now.
# 11
# Waiting for 2 minutes...
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /tmp/ipykernel_35/244425900.py in <cell line: 0>()
#       7
#       8     print("Waiting for 2 minutes...")
# ----> 9     time.sleep(120)
#      10     print("Resuming execution now.")
#      11
#
# KeyboardInterrupt:

# %%
docs
# Out:
# [(17.741650576283966,
#   'Wikipedia',
#   'for the winter olympics in st moritz switzerland total of eight sports venues were used the five venues used for the winter olympics were reused for these games three new venues were added for alpine skiing which had been added to the winter olympics program twelve years earlier in garmisch partenkirchen germany allied occupied germany during the games as of the bob run continues to be used for bobsleigh and the cresta run for skeleton while alpine skiing remains popular in st moritz venues venue sports capacity ref around the hills of st moritz cross country skiing nordic combined cross country skiing not listed cresta run skeleton not listed kulm ice hockey not listed olympiaschanze st moritz ski jumping nordic combined ski jumping not listed olympic stadium opening closing ceremonies figure skating ice hockey final speed skating not listed piz nair alpine skiing not listed st moritz celerina olympic bobrun bobsleigh not listed suvretta ice hockey not listed before the olympics st moritz hosted the winter olympics previously in all five venues from those games were reused for the winter olympics st moritz hosted the fibt world championships in four man four man two man two man and switzerland itself hosted the ice hockey world championships twice in between the and games doing so in and though neither took place in st moritz as an alpine skiing venue st moritz hosted the fis alpine world ski championships in during the olympics midway through the second run of the bobsleigh four man event water pipe burst which halted competition they still completed all four runs of the event after the olympics the ski jump was renovated in to get it to point of it closed in the bob run has hosted the fibt world championships sixteen more times since the games most recently in st moritz hosted its first recorded alpine skiing world cup event in the city hosted the alpine skiing world championships in and references'),
#  (17.518419295818905,
#   'Wikipedia',
#   'right horse guards parade hosted the beach volleyball events at the summer olympics in london copacabana stadium hosted the volleyball preliminaries for the summer olympics in rio de janeiro for the summer olympics there are venues that have been or will be used for beach volleyball beach location games events notes atlanta beach clayton county international park jonesboro clayton county georgia usa beach volleyball at the summer olympics artificial beach bondi beach bondi beach waverley council eastern suburbs sydney new south wales australia beach volleyball at the summer olympics ocean coast beach faliro olympic beach volleyball centre faliro coastal zone olympic complex faliro athens greece beach volleyball at the summer olympics artificial beach chaoyang park beach volleyball ground chaoyang park chaoyang district beijing china beach volleyball at the summer olympics artificial beach with sand imported from hainan horse guards parade whitehall london england uk beach volleyball at the summer olympics artificial beach on royal parade grounds copacabana beach copacabana stadium copacabana beach copacabana rio de janeiro brazil beach volleyball at the summer olympics ocean coast beach shiokaze park stadium shiokaze park tokyo waterfront tokyo kanto japan beach volleyball at the summer olympics see also list of olympic venues in volleyball references'),
#  (17.29930767868344,
#   'Wikipedia',
#   'kazakoshi park arena is an indoor arena located in karuizawa nagano japan constructed in with an opening ceremony taking place in it hosted the curling competition for the winter olympics in nagano because it was in karuizawa the town became the first venue to host events at both the summer and winter olympics at the summer olympics in tokyo karuizawa hosted the equestrian events references winter olympics official report volume pp icing org profile of the venue shinmai co jp winter olympics profile of the arena'),
#  (17.213456148257933,
#   'Wikipedia',
#   'the human rights party or kanakpak sethi manus is cambodian political party founded on july led by kem sokha critics allege that its foundation is meant to weaken opposition parties and is driven by the ruling party this sentiment however seems to be driven by the ruling party themselves as kem sokha has long been very vocal critic of the ruling cpp party at the time of its foundation the party claimed to have between and members nationwide human rights party is the first party in cambodia to adopt the check and balance system changing the culture of one man ruling parties which most parties in cambodia adopt it is also the first party in cambodia to have its major leaders elected in its convention its popularity has been dramatically increasing in cambodia especially in the countryside in the july parliamentary elections the ruling party won landslide majority and the human rights party took third place in it merged with the sam rainsy party to form the cambodia national rescue party electoral performance general election election leader votes seats position government kem sokha rd communal election election leader votes communes councillors position kem sokha rd references external links hrp website khmer french english habeas corpus net pro justice and democracy web publishes page in english and spanish on cambodia'),
#  (17.069092988406577,
#   'Wikipedia',
#   'the adler arena trade and exhibition center адлер арена is an seat speed skating oval in the olympic park sochi russia it opened in and looks like an iceberg or ice fault the center hosted the speed skating events at the winter olympics original plans for after the olympics were for the adler arena to be turned into an exhibition center it cost million to build the venue including the temporary works for the olympics before the olympics it hosted the russian speed skating championships in december and the world single distance speed skating championships from to march construction crystal face theme is supported by angular walls and triangular stained glass windows the gray and white color of the building enhances this impression the walls along the sides of the skating rink are made transparent so that spectators can look outside the skating center is designed to make the utmost use of local natural features track records men distance skater time date event ronald mulder february winter olympics stefan groothuis february winter olympics zbigniew bródka february winter olympics ivan skobrev february test competition sven kramer february winter olympics jorrit bergsma february winter olympics teampursuit laps jan blokhuijsensven kramerkoen verweij february winter olympics combination skater points date match michel mulder february winter olympics sprint dmitry lobkov december national championship all round ivan skobrev december national championship women distance skater time date event lee sang hwa february winter olympics zhang hong february winter olympics jorien ter mors february winter olympics ireen wüst february winter olympics martina sáblíková february winter olympics teampursuit laps marrit leenstrajorien ter morsireen wüst february winter olympics combination skater points date match lee sang hwa february winter olympics sprint olga fatkulina december national championship all round yekaterina shikhova december national championship source www info other uses the skating centre hosted the world robot olympiad russia hosted their fed cup world group semifinals tie at the adler arena references external links adler arena on www info'),
#  (16.649201347941414,
#   'Wikipedia',
#   'london hosted the olympic games in and the summer olympics made london the first city to have hosted the modern games of three olympiads london is the only city in the united kingdom to have ever hosted the olympics the united states is the only country to have hosted summer olympics on more occasions than the uk also london is the only city to have bid more than once and still hold record british participation in olympic events both as competitor and as host is the responsibility of the british olympic association summer olympics london olympics the summer olympics the games of the iv olympiad were the fifth modern olympic games and the third to be hosted outside of athens greece the international olympic committee considers them the fourth olympic games discounting the intercalated summer olympics the olympic games were scheduled to take place in rome but the eruption of mount vesuvius on april required the italian government to redirect funds away from the olympics the events took place between april and october with nations participating in events the british team easily topped the unofficial medal count finishing with three times as many medals as the second place united states summer olympics the summer olympics the games of the xiii olympiad were scheduled to be held in london awarded in they were however cancelled due to world war ii these games would have celebrated the th anniversary of the modern olympiad summer olympics the summer olympics the games of the xiv olympiad were the first to be held after world war ii with the summer olympics having been cancelled due to the war showing collective unity after the war nations competed in different events between july and august germany and japan were not invited to the games due to security reasons unlike the previous time the uk hosted the olympics the british athletes did not have high medal count finishing th in the unofficial medal count with only medals summer olympics the summer olympics the games of the xxx olympiad took place between july and august the london olympic bid was announced as the winner of the bidding process on july following unsuccessful bid attempts for previous olympics by manchester and birmingham team gb finished rd with gold medals and total medals representing their best medal haul since london first hosted the olympics in summer paralympics the summer paralympics were the fourteenth paralympics and took place between august and september at the summer olympics venues in london external links london olympic games official website london olympic games information portal commentary on olympic park'),
#  (16.59422882944778,
#   'Wikipedia',
#   'snow harp is cross country skiing venue located in hakuba nagano japan for the winter olympics the venue hosted the cross country skiing and the cross country skiing portion of the nordic combined events completed in test events were held in the venues consisted of three courses that were and in length respectively it hosted events during the games the most of any venue references winter olympics official report volume pp hakuba nagano venue profile shinmai co jp winter olympics profile snowjapan com profile'),
#  (16.554317816813846,
#   'Wikipedia',
#   'paris has hosted several olympiads and and will host in paris will be the second city in the modern games to have hosted three olympiads when paris hosts the summer olympics the other being london the french national olympic and sports committee oversees france interests in the olympics summer olympics paris summer olympics the summer olympics the games of the ii olympiad were the third modern olympics and the inaugural hosted outside of athens greece the international olympic committee considers them the second olympics discounting the intercalated summer olympics the summer olympics were held simultaneously with the world fair the events took place between may and october with nations participating in events the french team topped the unofficial medal count finishing with three times as many medals as the second place united states while fielding ten times as many athletes summer olympics the summer olympics the games of the viii olympiad were the second to be held after world war showing collective unity after the war nations competed in different events between may and july germany was not invited to the games due to security reasons unlike the previous time france hosted the olympics the french athletes did not have high medal count finishing rd in the unofficial medal count with only medals summer olympics the summer olympics the games of the xxxiii olympiad will take place from july to august the paris olympic bid was announced as the winner of the bidding process on september following unsuccessful bid attempts for previous olympiads summer paralympics the summer paralympics will be the seventeenth paralympics and will take place between august and september at the summer olympics venues in paris external links paris olympic games official website'),
#  (16.49412079690418,
#   'Wikipedia',
#   'los angeles hosted the olympic games in and and will host again in the summer olympics made los angeles the third city to have hosted the modern games of three olympiads los angeles will be the only city in the united states to have ever hosted the olympics three times american participation in olympic events both as competitor and as host is the responsibility of the united states olympic committee summer olympics the summer olympics the games of the olympiad were the eleventh modern olympic games and the eighth to be hosted outside of athens greece the international olympic committee considers them the tenth olympic games discounting the intercalated summer olympics the events took place between july and august with nations participating in events summer olympics the summer olympics the games of the xxiii olympiad was held between july and august the soviet union and its satellites boycotted the games summer olympics the summer olympics games of the xxxiiv olympiad will take place between july and august summer paralympics the summer paralympics will be the eighteen paralympic games and will take place in los angeles for the first time external links la'),
#  (16.373430619215696,
#   'Wikipedia',
#   'the faliro sports pavilion arena which is part of the faliro coastal zone olympic complex is an indoor arena in palaio faliro in athens greece it is nicknamed the little peace and friendship stadium due to its similarity in design and close proximity to the peace and friendship stadium it was the site of the athens summer olympics preliminary matches of handball as well as the taekwondo competition the arena seats for handball matches of olympics though only seats were made publicly available during the olympics history the arena was completed on december and it officially opened on august shortly before the olympics began in june the arena hosted the th mad video music awards held by mad tv and hosted by themis georgantas the prodigy had sold out concert event at the arena tiesto performed at the arena during his kaleidoscope world tour the arena is also known as long time venue for holiday on ice shows it also hosted the greek legends event by riot games league of legends lan tournament in june and it hosted the finals of the league of legends greek championship season in the th and january co organized by riot games ast and inspot references external links summer olympics official report volume pp gr profile faliro arena stadia gr'),
#  (16.3471222533474,
#   'Wikipedia',
#   'for the summer olympics there have been fourteen olympic sports that have been discontinued from the program as of the summer olympics in london for the summer olympics in rio de janeiro golf and rugby union were reinstated as olympic sports though the latter was as rugby sevens as of there have been eight baseball two basque pelota one cricket one croquet two golf one jeu de paume two lacrosse five polo one racquets five rugby union fifteen side four softball five tug of war and one water motorsports venues used for the summer olympics baseball and softball now governed by single international federation and thus treated by the international olympic committee ioc as two disciplines of single sport will be part of the summer olympics program in tokyo the sports are not included in paris plan for the games but are part of los angeles plan for the games baseball right atlanta fulton county stadium hosted the baseball events for the summer olympics games venue other sports hosted at venue for those games capacity ref los angeles dodger stadium demonstration none seoul jamsil baseball stadium demonstration none barcelona camp municipal de beisbol de viladecans none hospitalet de llobregat baseball stadium final none atlanta atlanta fulton county stadium none sydney blacktown olympic park softball sydney baseball stadium final modern pentathlon riding running athens olympic baseball centre none beijing wukesong baseball field none basque pelota right games venue other sports hosted at venue for those games capacity ref paris neuilly sur seine none not listed barcelona pavelló de la vall hebron demonstration volleyball volleyball basque pelota cricket right vélodrome de vincennes hosted the cricket matches at the summer olympics in paris games venue other sports hosted at venues for those games capacity ref paris vélodrome de vincennes cycling football gymnastics rugby union not listed croquet right games venue other sports hosted at venue for those games capacity ref paris bois de boulogne polo tug of war not listed jeu de paume right queen club hosted the jeu de paume events for the summer olympics in london games venue other sports hosted at venue for those games capacity ref london queen club racquets not listed lacrosse right games venue other sports hosted at venue for those games capacity ref st louis francis field archery athletics cycling football gymnastics roque tennis tug of war weightlifting wrestling london white city stadium archery athletics cycling track diving field hockey football gymnastics rugby union swimming tug of war water polo final wrestling polo right ostend hosted the polo events for the summer olympics in antwerp games venue other sports hosted at venue for those games capacity ref paris bois de boulogne croquet tug of war not listed london hurlingham club none not listed antwerp ostend sailing not listed paris bagatelle none saint cloud none berlin mayfield equestrian dressage racquets right games venue other sports hosted at venues for those games capacity ref london queen club jeu de paume not listed roque right games venue other sports hosted at venue for those games capacity ref st louis francis field archery athletics cycling football gymnastics lacrosse tennis tug of war weightlifting and wrestling rugby union fifteen side softball right blacktown olympic stadium hosted the softball events for the summer olympics in sydney games venue other sports hosted at venue for those games capacity ref atlanta golden park none sydney blacktown olympic park baseball athens olympic softball stadium none not listed beijing fengtai softball field none tug of war right games venue other sports hosted at venue for those games capacity ref paris bois de boulogne croquet polo not listed st louis francis field archery athletics cycling football gymnastics lacrosse roque tennis weightlifting and wrestling london white city stadium archery athletics cycling track diving field hockey football gymnastics lacrosse rug ...
#  (16.335045140998613,
#   'Wikipedia',
#   'poznań was bid by the city of poznań and the polish olympic committee to host the summer youth olympics poznan withdrew their bid on october for financial reasons history poznań was revealed to be one of the bidding cities for the summer youth olympics when the ioc announced who the applicants were on march poznań was one of the eight cities that hosted games during the uefa euro championship the stadion miejski hosted three matches during the championship poznań in last few years was host city of such sport events as the men indoor hockey world cup in the city hosted the academic canoeing world cup academic basketball world cup european male basketball cup and the european athletic cup for vets in the city hosted the academic futsal world cup and was one of the host cities for the uefa european under football championship on october the city council rejected the proposed budget for the bid there was lack of financial guarantees from the city organizer and the city withdrew its bid buenos aires was ultimately elected as the host city of the summer youth olympic games on july previous bids view of poznań old town poznań bid to host the summer youth olympics but lost to nanjing by only five votes they bid to host the summer youth olympics but failed to become candidate those games were ultimately awarded to singapore previous bids by other polish cities zakopane bid to host the winter olympics but lost to turin see also poland at the olympics bids for the summer youth olympics references'),
#  (16.33118298523432,
#   'Wikipedia',
#   'piscines bernat picornell is swimming venue situated in the olympic ring in montjuïc barcelona the venue consists of three swimming pools indoor pool outdoor pool and pool for diving it hosted the swimming events synchronized swimming events the water polo final and the swimming part of the modern pentathlon event for the summer olympics the swimming pools are for public use and are open all year long history the venue named after the catalan swimmer and founder of the spanish swimming federation bernat picornell richier was built to host the european aquatics championships in refurbishment works began for the olympics the main changes were that the training pool was covered and that temporary grandstands were installed boosting the capacity to more than spectators since the olympics the outdoor swimming pool with capacity for spectators has hosted several spanish and catalan swimming championships as well as the synchronized swimming events for the world aquatics championships in it hosted the water polo events for the world aquatics championships since the city of barcelona repeated as host ten years later see also piscina municipal de montjuïc references summer olympics official report volume pp external links official site'),
#  (16.297272864156565,
#   'Wikipedia',
#   'for the winter olympics in albertville france total of thirteen sports venues were used val isère has been part of the alpine skiing world cup since the late while tignes served as host of the first freestyle world ski championships in most of the venues used were constructed between and mid with the test events taking place in late and early it was the last winter olympics with an outdoor speed skating rink which led to weather issues for three of the ten events three cross country skiing events were run in snowstorms while the men km biathlon was found to be too short the downhill events in alpine skiing were criticized for being too steep freestyle skiing made its official debut at these games with the men winner being stormed after his win while the women winner won her event in snow storm la plagne hosted the skeleton world championships in while val isère hosted the alpine world ski championships in venues venue sports capacity ref anneau de vitesse speed skating la halle de glace olympique figure skating short track speed skating la plagne bobsleigh luge not listed les arcs speed skiing demonstration not listed les menuires alpine skiing men slalom not listed les saisies biathlon cross country skiing méribel alpine skiing women méribel ice palace ice hockey patinoire olympique de pralognan la vanoise curling demonstration théâtre des cérémonies ceremonies opening closing tignes freestyle skiing not listed tremplin du praz nordic combined ski jumping jumping nordic combined cross country skiing val isère alpine skiing men downhill super giant slalom giant slalom and combined not listed before the olympics albertville is part of the rhône alpes region in france that had hosted the winter olympics twice with chamonix in and grenoble in jean claude killy the triple gold medalist in the men alpine skiing event at the grenoble games had become successful businessman when he suggested the idea of the winter olympics in december to michel barnier politician in the savoie department proposal was sent to the albertville town council six months later followed regional studies done during presentation and media operations for the bid took place from to its awarding in by the international olympic committee after five rounds of voting albertville was selected over sofia bulgaria falun sweden val isère had its first alpine skiing world cup events run in december the olympic test held there in december was won by winter olympics men downhill gold medalist leonhard stock of austria tignes hosted of the first fis freestyle world ski championships in february construction on most of the venues took place between and mid in time for the late and early test events during the olympics this was the last winter olympics in which speed skating was held outdoors as result weather played factor in three of the ten events run in the women on february the start of the event was delayed one hour the let the outdoor oval ice harden warm weather delayed the women event for an hour on the th the following day the men event was held in steady rain norway geir karlstad the gold medalist in the men commented in the post race press conference that didn like soft ice up to now but now do this led to the international skating union passing rule after the winter games stating that all olympic speed skating competitions should be held indoors which it has been since the winter olympics in lillehammer for the alpine skiing downhill courses complaints were given that the courses were too steep on the men side the complaints from downhill skiers that it was more like super giant slalom course rather than classical downhill course the women course was long and had the steepest vertical drop ever at further making the women downhill challenge was an impending snowstorm that forced race officials to move up the start time and send the skiers out at shorter than usual intervals an intermittent fog also set in during the women downhill cross country skiing had sno ...
#  (16.220804878361456,
#   'Wikipedia',
#   'stadio olimpico di torino turin olympic stadium as football venue in for the winter olympics it hosted the opening and closing ceremonies for the winter olympics in turin italy total of fifteen sports venues were used venue construction ran from to cesana pariol had to have turns and modified following the luge world cup in january but they were not cleared out until october winds postponed the nordic combined team event for day many of the venues served as host for the winter universidade the following year venues city venue sports capacity ref oval lingotto speed skating palavela figure skating short track speed skating palasport olimpico ice hockey final stadio olimpico grande torino ceremonies opening closing torino esposizioni ice hockey mountain venue sports capacity ref bardonecchia snowboarding cesana pariol bobsleigh luge skeleton cesana san sicario biathlon pinerolo palaghiaccio curling pragelato nordic combined ski jumping ski jumping pragelato plan cross country skiing nordic combined cross country skiing san sicario fraiteve alpine skiing women combined downhill downhill super sauze oulx jouvencaux freestyle skiing sestriere borgata alpine skiing men combined downhill downhill super sestriere colle alpine skiing combined slalom giant slalom slalom before the olympics palavela during the winter olympics the venue hosted the figure skating and short track speed skating events during those games stadio olimpico in was known as stadio benito mussolini for the fifa world cup that took place that year the stadium hosted two matches including the quarterfinal match between czechoslovakia and switzerland turin was selected by the italian olympic committee to be selected to host the winter olympics in march it was awarded the winter olympics on june cesana pariol construction began in and was completed in after luge world cup test event in january that was abandoned to accidents this led to modifications of turns and and retest of the track that was approved by the international luge federation fil in october oval lingotto opened on december palavela constructed in was modified for the games to host figure skating and short track speed skating events san sicario fraiteve hosted an alpine skiing world cup in february and was modified to make the women super event more challenging torino esposizinoi was constructed in and refurbished in time for the games to host the preliminary ice hockey matches venues were selected between may and the summer of construction of the venues ran between the summers of and the venues were turned over for use of the games between the summer of and february new construction included cesana pariol cesana san sicario pragelato pragelato plan and sauze ouix jouvencaux while the other venues used were refurbished or expanded sustainability efforts were applied on all venues but the most noted in the olympics report were cesana pariol and pragelato plan the most expensive venue construction in the mountain area was cesana pariol at million while the most expensive city venue used for competition in the city area was oval lingotto at million during the olympics picture of turns through right to left of cesana pariol during the winter olympics bobsleigh luge and skeleton events took place at this venue the men curling bronze medal match at pinerolo between great britain and the united states was interrupted by streaker wearing rubber chicken as loin cloth at cesana pariol the women singles luge event had thirteen crashes or near crashes during the four runs among those who crashed were american samantha retrosi who was knocked unconscious at the end of the second run while italy anastasia oberstolz antonova crashed out during the first run during the men super alpine skiing event at sestriere borgata seventeen skiers had gone down the course in the morning portion of the event before it was halted to heavy snowfall the event was restarted in the afternoon with all morning results cancelled norway kj ...
#  (16.157061540484325,
#   'Wikipedia',
#   'for the winter olympics in innsbruck austria total of eight sports venues were used luge made its debut at these games but were marred by the death of british slider two weeks prior to the games second ski jumping event debuted and the best two out of three jumps were used in both events for the only time in the history of the winter olympics all eight venues would be used again when the winter games returned to innsbruck twelve years later though the venues would undergo renovations in time for the games venues venue sports capacity ref axamer lizum alpine skiing all but men downhill not listed bergiselschanze ski jumping large hill bob und rodelbahn igls bobsleigh luge not listed speed skating messehalle ice hockey olympiahalle figure skating ice hockey patscherkofel alpine skiing men downhill not listed seefeld biathlon cross country skiing nordic combined ski jumping normal hill not listed before the olympics before the winter games innsbruck hosted several world and european championships they hosted the alpine world ski championships both in and in innsbruck served as host to the fis nordic world ski championships innsbruck hosted its first bobsleigh world championships in in the two man event then hosted again in when the bobsleigh part of the track was used as test event for the games luge was also completed at the same time though kazimierz kay skrzypeski of great britain was killed in practice run on the luge part of the track two weeks before the start of the games igls also served as host of the european luge championships in though the track used was not constructed until since ski jumping season bergiselschanze has been part of the four hills tournament seefeld hosted the biathlon world championships in which also served as test event for the games during the olympics the ski jumping events were the only one in winter olympic history to use the best two out of three jumps for medals this saved finland veikko kankkonen in the normal hill event after he followed disastrous first jump with the longest second and the second longest third jumps after the olympics bergiselschanze continued to play host as one of the hills for the four hills tournament innsbruck would host the winter olympics twelve years later following the withdrawal of denver colorado in the united states for those games in late all eight venues from the games were used for the games with some improvements the bobsleigh and luge tracks were demolished and converted into an artificially refrigerated combination track the first of its kind in the world ski jumps at bergsiel and seefeld both had improving judging stations two new artificial ice rinks were built one for figure skating and the other for ice hockey eischnellaufen had new refrigeration done on its lap circuit references'),
#  (16.098253161597384,
#   'Wikipedia',
#   'lausanne was successful bid by the city of lausanne and the swiss olympic association to host the winter youth olympics the ioc selected the host city for the winter youth olympics at the th ioc session in kuala lumpur malaysia on july which lausanne won history applicant city phase the headquarters of the international olympic committee in lausanne lausanne bid for the winter youth olympics was confirmed on july the city is where the international olympic committee is headquartered lausanne is also home to many sport federations the bid was formally put forward in august lausanne was signed youth olympic game candidature procedure on december previous bids the city of lausanne made several bids in the past lausanne bid to host the summer olympics in but lost to berlin the city again bid for the summer olympics which was awarded to london however those games were cancelled because of the second world war london hosted the summer olympics lausanne bid to host the summer olympics but lost to rome previous bids by other swiss cities st moritz hosted the and winter olympics st moritz unsuccessfully bid to host the and winter olympics and lost to garmisch partenkirchen and squaw valley respectively sion bid to host the and winter olympics but lost to denver salt lake city and turin respectively denver pulled out as host of the games and innsbruck ultimately hosted the games venues lausanne palais de beaulieu figure skating short track curling stade pierre de coubertin opening and closing ceremonies medal ceremonies unil epfl sport centre speed skating centre intercommunal de glace de malley hockey lausanne campus olympic village jura prémanon france ski jumping biathlon nordic combined le brassus cross country skiing alps leysin les mosses les diablerets villars sur ollon notes and references external links official website'),
#  (16.08534300905383,
#   'Wikipedia',
#   'claude quenneville is canadian sports commentator in quebec he served as the french language radio voice of the montreal canadiens of the national hockey league he began his career at the age of at radio station cjmt am in chicoutimi and was later hired by the cbc as an announcer in in he hosted weekly variety show called tempo he became well known by becoming the announcer for radio broadcasts for games played by the montreal canadiens from to he also hosted the popular show la soirée du hockey on src and been long time commentator on olympic events including weightlifting events at the olympics in montreal diving events at the olympics in los angeles gymnastics events at the olympics in seoul athletics in atlanta at the olympics and ice hockey in nagano at the winter olympics quenneville has also covered the commonwealth games of edmonton of edinburgh and victoria his work as sports commentator has earned him two gémeaux awards the first in for the best sports commentator and the second in with gilles tremblay for la soirée du hockey references'),
#  (16.063460868705345,
#   'Wikipedia',
#   'five cities made the shortlist with their bids to host the summer olympics formally known as games of the xxviii olympiad which were awarded to athens on september the other shortlisted cities were rome cape town stockholm and buenos aires final selection in the first round of voting buenos aires and cape town tied with the lowest number of votes round two was therefore tie breaker round between the two cities with buenos aires being eliminated stockholm was the next city to be eliminated followed by cape town the final round saw athens receive enough votes to defeat rome and win the right to host the summer olympics official voting results athens was the leader in all rounds of voting except in round which was tie breaker due to first round tie between cape town and buenos aires cape town won that round over buenos aires before losing out in the th round host city election ballot results city country noc round run off round round round athens rome cape town stockholm buenos aires bidding cities candidate cities the colosseum one of rome most famous landmarks the acropolis of athens logolink city country national olympic committee result px athens hellenic olympic committee hoc winner the city of athens greece submitted bid for the games and won the election in the final round of voting defeating rome athens previously hosted the first modern olympic games in and bid for the summer olympics which were awarded to london but cancelled due to world war ii and the summer olympics athens campaign logo is represented by watercolor version of an olympic cauldron with the flame shaped as capital rome italian national olympic committee coni first runner up the city of rome italy submitted bid for the games and lost the election in the final round of voting being defeated by athens rome was previously awarded the summer olympics but the eruption of mount vesuvius forced the italians to return the games to the ioc and passed the honors to london it would have been the second time rome hosted the games after the summer olympics rome also bid for the the cancelled games and was recently candidate city for the summer olympics but withdrew its bid two years after rome lost their bid turin was awarded the winter olympics rome campaign logo depicts an stylized version of coloseum backgrounded by the sun cape town south african sports confederation and olympic committee sascoc second runner up the city of cape town south africa submitted bid for the games and received the third most votes tying with buenos aires in the first round of voting and winning the run off cape town never hosted the summer olympics or bid before it was africa first bid since alexandria egypt failed its bids to host the cancelled summer olympics and the summer olympics both of which were awarded to berlin had cape town won the rights to host the olympic games it would have been the first olympic games in the continent of africa south africa was awarded the fifa world cup on may and cape town was one of the host cities cape town campaign logo consists of an stylized map of africa colored with the colors of the olympic rings which is formed around the location of cape town in the south of the continent stockholm swedish olympic committee sok third runner up the city of stockholm sweden submitted bid for the games and was eliminated in the third round of voting stockholm previously hosted the summer olympics as well as co hosted the summer olympics with melbourne stockholm campaign logo depicts the statue man and pegasus located at millesgården just outside stockholm its hopes were ruined when sports arenas in stockholm and göteborg were damaged by explosive bombs and arson attacks by mats hinze px buenos aires argentine olympic committee coa fourth runner up the city of buenos aires argentina submitted bid for the games and was eliminated in run off against cape town since both cities tied in the first round of voting buenos aires never hosted the summer olympics but bi ...
#  (16.02462937593157,
#   'Wikipedia',
#   'dundumwezi is modified word from its original dundumwenze which means male mountain is constituency in chief siachitema in the south west of kalomo district of southern province zambia it is an underdeveloped remote constituency that lacks infrastructure and basic necessities and is often ignored by the government it lacks roads hospitals schools and housing demographics dundumwezi is inhabited by the tonga people of zambia august election in dundumwezi constituents favored an independent candidate over the popular united party for national development upnd candidate in the august general election voters showed overwhelming support for the leading opposition party president hakainde hichilema while only voted for the ruling party president edgar lungu who had never visited the area until july the elections were marred by violence instigated by the ruling patriotic front pf party against supporters of the opposition parties the counting process took three days the result was called into question by many opposition parties they accused the ruling party of delaying the release of the result granting election server access to foreign it specialists with connections to the ruling party disposing of opposition party ballot papers that were discovered in bin having pre marked ballot papers and allowing unverified ballot papers to be counted the area had been visited by sitting president once in and ignored thereafter following the visit of his excellence mr edgar lungu this year he has recognized and respected the cry of the people to develop dundumwezi the president is committed and has since included it in the national development plan despite having received few votes from the area tourism has also been extended in dundumwezi as development takes off references external links'),
#  (16.009292789330587,
#   'Wikipedia',
#   'communist party congress could refer to ruling or former ruling communist parties congress of the socialist unity party of germany national congress of the communist party of vietnam national congress of the communist party of china congress of the romanian communist party congress of the communist party of the soviet union congresses of the communist party of lithuania non ruling communist party congresses congresses of the communist party of brazil'),
#  (15.943671862094131,
#   'Wikipedia',
#   'there were six bids initially submitted for the summer olympics tokyo was ultimately elected as the host city at the th ioc session in buenos aires argentina on september bidding process the olympic bidding process begins with the submission of city application to the international olympic committee ioc by its national olympic committee noc and ends with the election of the host city by the members of the ioc during an ordinary session the process is governed by the olympic charter as stated in chapter rule since the process has consisted of two phases during the first phase which begins immediately after the bid submission deadline the applicant cities are required to answer questionnaire covering themes of importance to successful games organization this information allows the ioc to analyze the cities hosting capacities and the strengths and weaknesses of their plans following detailed study of the submitted questionnaires and ensuing reports the ioc executive board selects the cities that are qualified to proceed to the next phase the second phase is the true candidature stage the accepted applicant cities from now on referred to as candidate cities are required to submit second questionnaire in the form of an extended more detailed candidature file these files are carefully studied by the ioc evaluation commission group composed of ioc members representatives of international sport federations nocs athletes the international paralympic committee and international experts in various fields it is chaired by sir craig reedie the members of the evaluation commission then make four day inspection visits to each of the candidate cities where they check the proposed venues and are briefed about details of the themes covered in the candidature file the evaluation commission communicates the results of its inspections in report sent to the ioc members up to one month before the electing ioc session the ioc session in which host city is elected takes place in country that did not submit an application to stage the olympics the election is made by the assembled active ioc members excluding honorary and honor members each possessing one vote members from countries that have city taking part in the election cannot vote while the city is in the running the voting is conducted in succession of rounds until one bid achieves an absolute majority of votes if this does not happen in the first round the bid with the fewest votes is eliminated and another voting round begins in the case of tie for the lowest number of votes special runoff vote is carried out with the winner proceeding to the next round after each round the eliminated bid is announced following the announcement of the host city the successful bid delegation signs the host city contract with the ioc which delegates the of the games organisation to the city and respective noc bidding timeline the timeline of the host city selection process was approved by the international olympic committee ioc executive board as follows may ioc sent letters inviting the national olympic committees nocs to submit bids july and august ioc asked for nocs to submit letters regarding compliance with the world anti doping agency code by july the ioc also requested submissions of proposed dates if countries want to stage the games outside the normal period set by the ioc july to august the ioc responded to nocs on these points by the end of august september deadline to submit the names of cities interested in hosting the summer games september ioc confirmed that they had received six bids november ioc held an information seminar for applicants december ioc announced the drawing lots order of applicant cities february application files and guarantee letters submitted to the ioc may ioc executive board in quebec city decided which cities were to be approved as official candidate cities july august olympic games observers programme at the games of the xxx olympiad in london november olympic games debr ...
#  (15.932951385563095,
#   'Wikipedia',
# ...
#  (15.444647559845158,
#   'Wikipedia',
#   'the popular action of equatorial guinea is political party in the equatorial guinea it is led by carmelo mba bacalé it is currently one of many opposition parties in the country banned by the ruling party the democratic party of equatorial guinea the ruling party since despite being an illegal party bacalé gained of the country vote for the ap in the equatoguinean presidential election references'),
#  (15.43243148059007,
#   'Wikipedia',
#   'the winter olympics which would have been officially known as the were to have been celebrated from to february in sapporo japan but the games were eventually cancelled due to the onset of world war ii sapporo subsequently hosted the winter olympics history sapporo was selected to be the host of the fifth edition of the winter olympics scheduled february but japan gave the games back to the ioc in july after the outbreak of the second sino japanese war in the ioc then decided to give the winter olympics to st moritz switzerland which had hosted it in however the swiss organizers believed that ski instructors should be considered professionals the ioc was not of that mind and the games were withdrawn again in the spring of the ioc gave the winter olympics now scheduled for february to garmisch partenkirchen germany where the previous games had been held five months later on september germany invaded poland igniting world war ii and the winter games were cancelled in november likewise the games awarded in to cortina ampezzo italy were cancelled in st moritz held the first post war games in while cortina ampezzo hosted in germany has not hosted the winter olympics since on july munich lost to pyeongchang south korea to host the winter games see also external links planned program for the winter olympics in sapporo and garmisch partenkirchen'),
#  (15.390881429605596,
#   'Wikipedia',
#   'olimpiysky pool moscow as seen in the swimming pool at the olimpiysky sports complex is covered swimming centre in moscow russia the venue built for the summer olympics makes up the olimpiysky sports complex architectural ensemble together with the olimpiysky arena during the olympics it hosted the swimming diving water polo and the swimming part of the modern pentathlon events it also hosted short course world championships the venue consists of swimming pool with capacity for spectators separated by an acoustic partition from the diving pool with capacity for spectators see also olympic pool at the luzhniki olympic complex references external links official website of the olympiisky sports complex'),
#  (15.38801518613207,
#   'Wikipedia',
#   'guadalajara was bid by the city of guadalajara and the comité olímpico mexicano to host the summer youth olympics history on february guadalajara bid was selected over monterrey bid to bid to host the summer youth olympics by an inner voting from the mexico national olympic committee it was reported in august that the bid may be in danger due to the debt created by the pan american games guadalajara failed to become candidate city for the games when the ioc selected the candidate cities on february buenos aires was ultimately elected as the host city of the summer youth olympic games on july previous bids from other mexican cities the rotonda de los jaliscienses ilustres at night guadalajara was elected previously to bid to host the summer youth olympics but withdrew their bid following this report nanjing was ultimately awarded the games mexico city hosted the summer olympic games in mexico city made two bids prior to their bid they bid for the and summer olympics but lost to melbourne and rome respectively guadalajara had previously hosted the pan american games and bid for the world aquatics championships but withdrew the championships were awarded to budapest see also monterrey bid for the summer youth olympics mexico at the olympics bids for the summer youth olympics references'),
#  (15.384197671936011,
#   'Wikipedia',
#   'the popular union of equatorial guinea is political party in the equatorial guinea it is led by daniel martinez ayecaba the party was originally banned by the ruling democratic party of equatorial guinea the ruling party since but was legalized in may the up candidate archivaldo montelo biribé gained of the country vote in the equatoguinean presidential election references'),
#  (15.375723900710383,
#   'Wikipedia',
#   'birkebeineren ski stadium is cross country skiing and biathlon venue located in lillehammer norway situated from the town center and at above mean sea level it has two stadium areas one for cross country and one for biathlon the former has capacity for spectators and the latter for the venue was built for the winter olympics costing million norwegian krone nok it was subsequently used by the winter paralympics for paralympic nordic skiing and paralympic biathlon after the games ownership was transferred to the municipal lillehammer olympiapark the venue has since been used for one biathlon world cup three fis cross country world cup and nine fis nordic combined world cup tournaments the latter with the ski jumping competition taking place at the nearby lysgårdsbakkene ski jumping arena birkebeineren hosted the winter youth olympics construction the location of the venue was decided in january following lillehammer successful bid to host the winter olympics construction was managed by the lillehammer olympic organizing committee looc architects were arkitekter and the main consultant was tonning lieng construction started in early before planning was completed and lasted until the construction work was subcontracted to several companies landscaping was completed in the facilities used concrete and wood as the main materials the stadium included of temporary buildings building converted to riding center after the olympics and tent the land around the venue is swamp and most of the surface soil had to be removed and replaced with harder earth the soil was used as fertilizer or fill in other parts of the arena creek had to be bypassed with long pipe the arena is also so flat that drainage system had to be installed after the olympics four temporary overpasses were removed construction of the tracks was done to minimize the impact on the forest the venue cost nok million and was inaugurated on november with an international biathlon competition in december the looc stated that they wanted to upgrade the stadium spectator capacity but that the transport systems would not allow more people in the stadium had world cup tournaments in biathlon and cross country skiing as trial before the olympics during several events the computer system controlling the scoreboard and television scores collapsed president johan baumann of the norwegian ski federation criticized the venue and demanded that new stadium be built he stated that the stadium had been built to optimize television pictures and that it had insufficient facilities for the spectators in particular he criticized the fact that the spectators were too far away from the skiers and the lack of television screen and more scoreboards in may the looc announced that the stadium would be expanded for another people before the olympics on september the ownership of the venue was transferred from the looc to lillehammer municipality via the subsidiary lillehammer olympiavekst which later changed its name to lillehammer olympiapark in october the forest along the tracks were partially cleared to allow spectators without tickets to watch the events facilities the arena covers an area of and is from the town center for the olympics of cross country tracks and of biathlon tracks were built there are two stadiums one for cross country skiing and one for biathlon the former has spectator capacity for while the latter has capacity for in addition up to people watched the events the trackside during the olympics permanent buildings include finishing house for biathlon finishing house for cross country plant room the cross country stadium is long while the biathlon stadium is long the biathlon stadium has shooting stations the facility has kva transformer with an additional transformer used during the olympics critical systems such as computers and time keeping equipment have an uninterruptible power supply as recreational venue birkebeineren connects to of skiing tracks including lighted track wh ...
#  (15.35143907463622,
#   'Wikipedia',
#   'right start at the cresta run in st moritz host of the skeleton events for both the and winter olympics turn at the whistler sliding centre in for the winter olympics in vancouver the venue hosted the skeleton events for the winter olympics there have been six venues that have been or will be used for skeleton when the winter olympics were in st moritz they took place at the cresta run for both and since being re introduced at the winter olympics skeleton has shared the same venue with the other sliding sports of bobsleigh and luge games venue other sports hosted at venue for those games capacity ref st moritz cresta run none not listed st moritz cresta run none not listed salt lake city utah olympic park includes bobsleigh luge and skeleton track bobsleigh luge nordic combined ski jumping ski jumping ski jumping bobsleigh luge skeleton turin cesana pariol bobsleigh luge vancouver the whistler sliding centre bobsleigh luge sochi sliding center sanki bobsleigh luge pyeongchang alpensia sliding centre bobsleigh luge references'),
#  (15.33618124931852,
#   'Wikipedia',
#   'aerial view of the current bobsleigh luge and skeleton track at the winter games this was where the luge track was located the bobsleigh track used for the and winter olympics no longer in use is seen at the lower part of the picture for the winter olympics in lake placid new york united states total of seven sports venues were used all five of the venues used for the winter olympics were also used at the winter games with adjustments these adjustments included electronic scoreboards increased refrigeration and the addition of separate luge track this was the last winter olympics where there were separate bobsleigh and luge tracks the closest finish in olympic history in cross country skiing led skiing officials to time future events in hundredths of second rather than tenths of second this would also apply to biathlon events eric heiden of the united states won five gold medals at the speed skating oval while the miracle on ice took place between americans and soviets at the olympic center in the late the luge track was demolished and new combination track was constructed in time for the only winter goodwill games held the sliding venue was named to the american national register of historical places in february venues map of the venues in lake placid venue sports capacity ref intervales ski hill nordic combined ski jumping ski jumping lake placid equestrian stadium opening ceremonies lake placid olympic sports complex cross country biathlon center biathlon cross country skiing nordic combined cross country skiing not listed mt van hoevenberg bob and luge run bobsleigh luge separate tracks bobsleigh olympic center arena figure skating ice hockey olympic arena james sheffield speed skating oval speed skating whiteface mountain alpine skiing not listed before the olympics lake placid hosted the winter olympics in with all five venues used for those games being used for the winter olympics the city made four unsuccessful bids for the winter olympics in and before being awarded the winter olympics by the international olympic committee ioc in between the winter games and the winter games lake placid played host to winter sports championships the first time many of them were held outside of europe after the games the speedskating oval hosted the world allround speed skating championships for men the bob run hosted the fibt world championships in and in the fis nordic world ski championships took place at the ski jump used for the games for the ski jumping and the ski jumping part of the nordic combined event biathlon held their first world championships outside of europe at lake placid in when lake placid was awarded the winter games in venue adjustments were needed for the alpine skiing events snow making equipment was used this was used to make of man made snow to cover all of the trails used for the events six new ski lifts and electronic timing scoring systems were also constructed for the nordic skiing events cross country skiing nordic combined ski jumping total of event officials were sent as observers to the world championships in lahti finland to understand the venue needs for the games for the km race total of was purchased and trail system was created that involved tree clearing man made snow was also applied for the cross country skiing trail races over km in length were modified to meet the snow requirements as defined by the international ski federation an electronic scoreboard was installed for the cross country skiing events this information was passed onto organizers for the winter olympics in sarajevo two new ski jumps were constructed the jump was constructed between may and december construction for the jump also started in may but was not done until the february test event to construction delays caused by the bankruptcy of the steel contractor biathlon used trails similar to cross country skiing though separate finish area was used protective shooting area of was built for the competition of for shooting st ...
#  (15.295942665184704,
#   'Wikipedia',
#   'is mountain located in yamanouchi nagano japan for the winter olympics it hosted the alpine skiing slalom and snowboarding giant slalom events during the games the mountain suffered mild earthquake that registered on the richter magnitude scale but the skiing events continued references winter olympics official report volume pp poor skiing conditions nothing new to whistler february toronto observer article accessed september shinmai co jp winter olympics venue profile'),
#  (15.244994561315828,
#   'Wikipedia',
#   'the camp olímpic de tir amb arc was temporary venue located in barcelona it hosted the archery competitions for the summer olympics it was located in site at the ronda de dalt next to the pavelló de la vall hebron in the barcelona district of horta guinardó after the olympics it was remodelled into ciutat esportiva municipal vall hebron teixonera which consists of two football soccer fields rugby field and an annexe service area references summer olympics official report volume pp'),
#  (15.21769728323561,
#   'Wikipedia',
#   'the hon clyde mascoll is politician from barbados he is former leader of the democratic labour party dlp in mascoll unsuccessfully led the party in an election against the ruling barbados labour party blp however after internal disagreement within the dlp mascoll crossed the floor to become member of the ruling blp in becoming minister of state in the ministry of finance he was defeated in his st michael north west constituency by the dlp christopher sinckler in the january general election receiving of the vote references')]

# %% [markdown]
# StrategyQA

# %%
from datasets import load_dataset

# ─── Load StrategyQA (ChilleD mirror) ───────────────────────────────────────
# This will pull 2,780 train examples and 490 test examples
train_ds = load_dataset("ChilleD/StrategyQA", split="train")
test_ds  = load_dataset("ChilleD/StrategyQA", split="test")

print(f"Train size: {len(train_ds)}")
print(f"Test  size: {len(test_ds)}")
# Inspect a single example
print(train_ds[0])
# Out:
# README.md:   0%|          | 0.00/433 [00:00<?, ?B/s]
# (…)-00000-of-00001-506370352f622815.parquet:   0%|          | 0.00/369k [00:00<?, ?B/s]
# (…)-00000-of-00001-bae602f3ee37f4ca.parquet:   0%|          | 0.00/161k [00:00<?, ?B/s]
# Generating train split:   0%|          | 0/1603 [00:00<?, ? examples/s]
# Generating test split:   0%|          | 0/687 [00:00<?, ? examples/s]
# Train size: 1603
# Test  size: 687
# {'qid': '4fd64bb6ce5b78ab20b6', 'term': 'Mixed martial arts', 'description': 'full contact combat sport', 'question': 'Is Mixed martial arts totally original from Roman Colosseum games?', 'answer': False, 'facts': 'Mixed Martial arts in the UFC takes place in an enclosed structure called The Octagon. The Roman Colosseum games were fought in enclosed arenas where combatants would fight until the last man was standing. Mixed martial arts contests are stopped when one of the combatants is incapacitated. The Roman Colosseum was performed in front of crowds that numbered in the tens of thousands. Over 56,000 people attended UFC 193.'}

# %%
# ─── Cell: load_or_compute_docs helper ──────────────────────────────────────
import os, json, hashlib, heapq, numpy as np
from nltk.tokenize    import word_tokenize
from rank_bm25        import BM25Okapi
from tqdm.auto        import tqdm


CACHE_DIR = "cache"
DUMP_PATH = "/kaggle/input/wikidump/wikipedia-dump.txt"


def get_cache_paths(question: str):
    h = hashlib.sha256(question.encode("utf-8")).hexdigest()[:8]
    return (
        os.path.join(CACHE_DIR, f"docs_{h}.json"),
        os.path.join(CACHE_DIR, f"sents_{h}.json")
    )

def load_or_compute_docs(
    question: str,
    top_d: int = 5,
    chunk_size: int = 50_000
) -> list[tuple[float,str,str]]:
    """
    Returns top_d (score, title, paragraph) for `question`.
    Caches to CACHE_DIR/docs_<hash>.json on first run, then reloads.
    """
    docs_path, _ = get_cache_paths(question)

    # 1) Try loading cached
    if os.path.exists(docs_path):
        with open(docs_path, "r", encoding="utf-8") as f:
            data = json.load(f)
        return [(d["score"], d["title"], d["para"]) for d in data]

    # 2) Otherwise compute
    queries = generate_multiview_queries(question)
    heap, buffer, titles = [], [], []

    for title, para in tqdm(iter_wiki_paragraphs(DUMP_PATH), desc="Topic retrieve"):
        buffer.append(para); titles.append(title)
        if len(buffer) >= chunk_size:
            _process_chunk_multiview(buffer, titles, queries, top_d, heap)
            buffer, titles = [], []

    # process leftovers
    if buffer:
        _process_chunk_multiview(buffer, titles, queries, top_d, heap)

    docs = sorted(heap, key=lambda x: -x[0])[:top_d]

    # 3) Cache to disk
    os.makedirs(CACHE_DIR, exist_ok=True)
    with open(docs_path, "w", encoding="utf-8") as f:
        json.dump(
            [{"score": s, "title": t, "para": p} for s, t, p in docs],
            f, ensure_ascii=False, indent=2
        )

    return docs

# %% [markdown]
# delete it

# %%
# ─── Cell 9 (cache-only): Batch Process Questions via Cached Docs/Sents ────
import os, json, hashlib


CACHE_DIR = "cache"
DUMP_PATH = "/kaggle/input/wikidump/wikipedia-dump.txt"


def get_cache_paths(question: str):
    h = hashlib.sha256(question.encode("utf-8")).hexdigest()[:8]
    return (
        os.path.join(CACHE_DIR, f"docs_{h}.json"),
        os.path.join(CACHE_DIR, f"sents_{h}.json")
    )

questions = [
    "What is the ruling party of the country that hosted the 2016 Olympics?",
    "Is the Eiffel Tower located in Paris?",
    "Was Barack Obama born in the United States?"
    # … add more …
]

for q in questions:
    print(f"\n--- {q} ---")
    docs_path, sents_path = get_cache_paths(q)

    # 1) Load docs from cache
    if not os.path.exists(docs_path):
        raise FileNotFoundError(f"{docs_path} not found. Run load_or_compute_docs() once first.")
    with open(docs_path, "r", encoding="utf-8") as f:
        docs = [(d["score"], d["title"], d["para"]) for d in json.load(f)]
    print(f"🔄 Loaded {len(docs)} paragraphs from {docs_path}")

    # 2) Load sents from cache
    if not os.path.exists(sents_path):
        raise FileNotFoundError(f"{sents_path} not found. Run load_or_compute_sents() once first.")
    with open(sents_path, "r", encoding="utf-8") as f:
        top_sents = [(d["sent"], d["score"]) for d in json.load(f)]
    print(f"🔄 Loaded {len(top_sents)} sentences from {sents_path}")

    # 3) (Optional) print a sample
    print("\nSample paragraph:", docs[0][2][:100], "…")
    print("Sample sentence:", top_sents[0][0])
# Out:
# --- What is the ruling party of the country that hosted the 2016 Olympics? ---
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# /tmp/ipykernel_35/3580777964.py in <cell line: 0>()
#      27     # 1) Load docs from cache
#      28     if not os.path.exists(docs_path):
# ---> 29         raise FileNotFoundError(f"{docs_path} not found. Run load_or_compute_docs() once first.")
#      30     with open(docs_path, "r", encoding="utf-8") as f:
#      31         docs = [(d["score"], d["title"], d["para"]) for d in json.load(f)]
#
# FileNotFoundError: cache/docs_d866e7b8.json not found. Run load_or_compute_docs() once first.

# %%
# ─── Cell 9: Batch Process Multiple Questions ───────────────────────────────
questions = [
    "What is the ruling party of the country that hosted the 2016 Olympics?",
    "Is the Eiffel Tower located in Paris?",
    "Was Barack Obama born in the United States?"
    # … add more …
    ]
for q in questions:
    print(f"\n--- {q} ---")
    docs     = load_or_compute_docs(q)
    sents    = load_or_compute_sents(q, docs)
    print("Docs:", len(docs), "Sentences:", len(sents))
# Out:
# --- What is the ruling party of the country that hosted the 2016 Olympics? ---
# Topic retrieve: 0it [00:00, ?it/s]

# %%
# need to update the cell 9 for that docs thingy.

# %%
import time

count = 0
while True:
    print(count)
    count += 1
    
    print("Waiting for 2 minutes...")
    time.sleep(120)
    print("Resuming execution now.")

# %% [markdown]
# saving the model state

# %%
# ─── Saving the model state ───────────────────────────────────────────────────
import torch

# Assume `model` is your DisentangledReasoner instance on `device`
save_path = "disentangled_reasoner.pt"
torch.save(model.state_dict(), save_path)
print(f"✅ Model weights saved to {save_path}")

# %%
# ─── Reloading the model state ───────────────────────────────────────────────
import torch

# 1) Re-instantiate the model architecture
model = DisentangledReasoner().to(device)

# 2) Load the saved weights
checkpoint = torch.load("disentangled_reasoner.pt", map_location=device)
model.load_state_dict(checkpoint)

# 3) Set to eval mode (if you’re doing inference)
model.eval()
print("✅ Model weights loaded and ready for inference")

# %%
torch.save({
    "model_state": model.state_dict(),
    "optim_state": optimizer.state_dict(),
    "epoch": current_epoch,
    "loss": last_loss,
}, "checkpoint.pt")

# %%
ckpt = torch.load("checkpoint.pt")
model.load_state_dict(ckpt["model_state"])
optimizer.load_state_dict(ckpt["optim_state"])
start_epoch = ckpt["epoch"] + 1
